# %%
#!/usr/bin/env python3

# %% [markdown]
# This file illustrates how you might experiment with the HMM interface.
# You can paste these commands in at the Python prompt, or execute `test_en.py` directly.
# A notebook interface is nicer than the plain Python prompt, so we provide
# a notebook version of this file as `test_en.ipynb`, which you can open with
# `jupyter` or with Visual Studio `code` (run it with the `nlp-class` kernel).

# %%
import logging
import math
import os
from pathlib import Path

# %%
from corpus import TaggedCorpus
from eval import eval_tagging, model_cross_entropy, viterbi_error_rate,write_tagging
from hmm import HiddenMarkovModel
from crf import ConditionalRandomField

# %% [markdown]
# Set up logging.

# %%
logging.root.setLevel(level=logging.INFO)
log = logging.getLogger("test_en")       # For usage, see findsim.py in earlier assignment.
logging.basicConfig(format="%(levelname)s : %(message)s", level=logging.INFO)  # could change INFO to DEBUG

# %% [markdown]
# Switch working directory to the directory where the data live.  You may need to edit this line.

# %%
os.chdir("../data")

# %%
entrain = TaggedCorpus(Path("ensup"), Path("enraw"))                               # all training
ensup =   TaggedCorpus(Path("ensup"), tagset=entrain.tagset, vocab=entrain.vocab)  # supervised training
endev =   TaggedCorpus(Path("endev"), tagset=entrain.tagset, vocab=entrain.vocab)  # evaluation
print(f"{len(entrain)=}  {len(ensup)=}  {len(endev)=}")
# Out:
# INFO : Read 191873 tokens from ensup, enraw
# INFO : Created 26 tag types
# INFO : Created 18461 word types
# len(entrain)=8064  len(ensup)=4051  len(endev)=996

# %%
known_vocab = TaggedCorpus(Path("ensup")).vocab    # words seen with supervised tags; used in evaluation
log.info(f"Tagset: f{list(entrain.tagset)}")
# Out:
# INFO : Read 95936 tokens from ensup
# INFO : Created 26 tag types
# INFO : Created 12466 word types
# INFO : Tagset: f['W', 'J', 'N', 'C', 'V', 'I', 'D', ',', 'M', 'P', '.', 'E', 'R', '`', "'", 'T', '$', ':', '-', '#', 'S', 'F', 'U', 'L', '_EOS_TAG_', '_BOS_TAG_']

# %%
hmm = HiddenMarkovModel.load("../code/models/en_hmm_awesome.pkl")  # reset to supervised model (in case you're re-executing this bit)
# write_tagging(hmm, endev, Path("endev_hmm_posterior.output"))
def look_at_your_data_posterior(model, dev, N):
    for m, sentence in enumerate(dev):
        if m >= N: break
        posterior = model.posterior_decode(sentence.desupervise(), endev)
        counts = eval_tagging(predicted=posterior, gold=sentence, 
                              known_vocab=known_vocab)
        num = counts['NUM', 'ALL']
        denom = counts['DENOM', 'ALL']
        
        log.info(f"Gold:    {sentence}")
        log.info(f"Viterbi: {posterior}")
        log.info(f"Loss:    {denom - num}/{denom}")
        log.info(f"Acc:    {num}/{denom}")
        xent = -model.logprob(sentence, endev) / len(sentence)  # measured in nats
        log.info(f"Cross-entropy: {xent/math.log(2)} nats (= perplexity {math.exp(xent)})\n---")

look_at_your_data_posterior(hmm, endev, 10)
# Out:
# INFO : Loaded model from ../code/models/en_hmm_awesome.pkl
# INFO : Gold:    ``/` We/P 're/V strongly/R _OOV_/V that/I anyone/N who/W has/V eaten/V in/I the/D cafeteria/N this/D month/N have/V the/D shot/N ,/, ''/' Mr./N Mattausch/N added/V ,/, ``/` and/C that/D means/V virtually/R everyone/N who/W works/V here/R ./.
# INFO : Viterbi: ``/` We/P 're/V strongly/R _OOV_/V that/I anyone/N who/W has/V eaten/V in/I the/D cafeteria/J this/D month/N have/V the/D shot/V ,/, ''/' Mr./N Mattausch/M added/V ,/, ``/` and/C that/W means/V virtually/R everyone/N who/W works/V here/R ./.
# INFO : Loss:    4/34
# INFO : Acc:    30/34
# INFO : Cross-entropy: 11.832855224609375 nats (= perplexity 3647.9112369468235)
# ---
# INFO : Gold:    I/P was/V _OOV_/V to/T read/V the/D _OOV_/N of/I facts/N in/I your/P Oct./N 13/C editorial/N ``/` _OOV_/N 's/P _OOV_/N _OOV_/N ./. ''/'
# INFO : Viterbi: I/P was/V _OOV_/R to/T read/V the/D _OOV_/N of/I facts/N in/I your/P Oct./N 13/C editorial/J ``/` _OOV_/E 's/P _OOV_/M _OOV_/- ./. ''/'
# INFO : Loss:    5/21
# INFO : Acc:    16/21
# INFO : Cross-entropy: 24.64159393310547 nats (= perplexity 26173334.773420565)
# ---
# INFO : Gold:    It/P is/V the/D _OOV_/J guerrillas/N who/W are/V aligned/V with/I the/D drug/N traffickers/N ,/, not/R the/D left/J _OOV_/N ./.
# INFO : Viterbi: It/P is/V the/D _OOV_/F guerrillas/S who/W are/V aligned/V with/I the/D drug/N traffickers/N ,/, not/R the/D left/V _OOV_/R ./.
# INFO : Loss:    4/18
# INFO : Acc:    14/18
# INFO : Cross-entropy: 16.039230346679688 nats (= perplexity 67342.5146910516)
# ---
# INFO : Gold:    This/D information/N was/V _OOV_/V from/I your/P own/J news/N stories/N on/I the/D region/N ./.
# INFO : Viterbi: This/D information/N was/V _OOV_/R from/I your/P own/J news/N stories/N on/I the/D region/N ./.
# INFO : Loss:    1/13
# INFO : Acc:    12/13
# INFO : Cross-entropy: 13.096787452697754 nats (= perplexity 8760.436595337365)
# ---
# INFO : Gold:    _OOV_/J _OOV_/J government/N _OOV_/N of/I the/D ``/` _OOV_/F ''/' was/V due/J to/T the/D drug/N _OOV_/N '/P history/N of/I _OOV_/V out/R _OOV_/N in/I the/D _OOV_/N ./.
# INFO : Viterbi: _OOV_/` _OOV_/F government/N _OOV_/V of/I the/D ``/` _OOV_/E ''/' was/V due/J to/T the/D drug/N _OOV_/, '/P history/N of/I _OOV_/$ out/R _OOV_/V in/I the/D _OOV_/N ./.
# INFO : Loss:    7/25
# INFO : Acc:    18/25
# INFO : Cross-entropy: 29.614383697509766 nats (= perplexity 821897551.6762545)
# ---
# INFO : Gold:    Mary/N _OOV_/N Palo/N Alto/N ,/, Calif/N ./.
# INFO : Viterbi: Mary/N _OOV_/I Palo/N Alto/N ,/, Calif/N ./.
# INFO : Loss:    1/7
# INFO : Acc:    6/7
# INFO : Cross-entropy: 17.614578247070312 nats (= perplexity 200685.75274230217)
# ---
# INFO : Gold:    I/P suggest/V that/I The/D Wall/N Street/N Journal/N -LRB-/- as/R well/R as/I other/J U.S./N news/N publications/N of/I like/J mind/N -RRB-/- should/M put/V its/P money/N where/W its/P mouth/N is/V :/: _OOV_/V computer/N equipment/N to/T replace/V that/I damaged/V at/I El/N _OOV_/N ,/, buy/V ad/N space/N ,/, publish/V stories/N under/I the/D _OOV_/N of/I El/N _OOV_/N journalists/N ./.
# INFO : Viterbi: I/P suggest/V that/I The/D Wall/N Street/N Journal/N -LRB-/- as/R well/R as/I other/J U.S./N news/N publications/N of/I like/I mind/N -RRB-/- should/M put/V its/P money/N where/W its/P mouth/M is/V :/: _OOV_/D computer/N equipment/N to/T replace/V that/W damaged/V at/I El/N _OOV_/N ,/, buy/V ad/N space/N ,/, publish/V stories/N under/I the/D _OOV_/N of/I El/N _OOV_/I journalists/N ./.
# INFO : Loss:    5/53
# INFO : Acc:    48/53
# INFO : Cross-entropy: 15.704708099365234 nats (= perplexity 53405.791633508794)
# ---
# INFO : Gold:    Perhaps/R an/D arrangement/N could/M be/V worked/V out/R to/T ``/` sponsor/V ''/' El/N _OOV_/N journalists/N and/C staff/N by/I paying/V for/I added/V security/N in/I exchange/N for/I exclusive/J stories/N ./.
# INFO : Viterbi: Perhaps/R an/D arrangement/N could/M be/V worked/V out/R to/T ``/` sponsor/N ''/' El/N _OOV_/I journalists/N and/C staff/N by/I paying/V for/I added/J security/N in/I exchange/N for/I exclusive/J stories/N ./.
# INFO : Loss:    3/27
# INFO : Acc:    24/27
# INFO : Cross-entropy: 12.938546180725098 nats (= perplexity 7850.378544635438)
# ---
# INFO : Gold:    _OOV_/V El/N _OOV_/N 's/P courage/N with/I real/J support/N ./.
# INFO : Viterbi: _OOV_/D El/N _OOV_/, 's/P courage/N with/I real/J support/N ./.
# INFO : Loss:    2/9
# INFO : Acc:    7/9
# INFO : Cross-entropy: 22.36467933654785 nats (= perplexity 5400565.132127068)
# ---
# INFO : Gold:    Douglas/N B./N Evans/N
# INFO : Viterbi: Douglas/N B./N Evans/N
# INFO : Loss:    0/3
# INFO : Acc:    3/3
# INFO : Cross-entropy: 11.576026916503906 nats (= perplexity 3053.032064500592)
# ---

# %%
look_at_your_data(hmm, endev, 10)
# Out:
# INFO : Gold:    ``/` We/P 're/V strongly/R _OOV_/V that/I anyone/N who/W has/V eaten/V in/I the/D cafeteria/N this/D month/N have/V the/D shot/N ,/, ''/' Mr./N Mattausch/N added/V ,/, ``/` and/C that/D means/V virtually/R everyone/N who/W works/V here/R ./.
# INFO : Viterbi: ``/` We/P 're/V strongly/R _OOV_/V that/I anyone/N who/W has/V eaten/V in/I the/D cafeteria/J this/D month/N have/V the/D shot/N ,/, ''/' Mr./N Mattausch/, added/V ,/, ``/` and/C that/W means/V virtually/R everyone/, who/W works/V here/R ./.
# INFO : Loss:    4/34
# INFO : Acc:    30/34
# INFO : Cross-entropy: 11.832855224609375 nats (= perplexity 3647.9112369468235)
# ---
# INFO : Gold:    I/P was/V _OOV_/V to/T read/V the/D _OOV_/N of/I facts/N in/I your/P Oct./N 13/C editorial/N ``/` _OOV_/N 's/P _OOV_/N _OOV_/N ./. ''/'
# INFO : Viterbi: I/P was/V _OOV_/R to/T read/V the/D _OOV_/N of/I facts/N in/I your/P Oct./N 13/C editorial/J ``/` _OOV_/` 's/P _OOV_/M _OOV_/R ./. ''/'
# INFO : Loss:    5/21
# INFO : Acc:    16/21
# INFO : Cross-entropy: 24.64159393310547 nats (= perplexity 26173334.773420565)
# ---
# INFO : Gold:    It/P is/V the/D _OOV_/J guerrillas/N who/W are/V aligned/V with/I the/D drug/N traffickers/N ,/, not/R the/D left/J _OOV_/N ./.
# INFO : Viterbi: It/P is/V the/D _OOV_/N guerrillas/, who/W are/V aligned/R with/I the/D drug/N traffickers/N ,/, not/R the/D left/V _OOV_/R ./.
# INFO : Loss:    5/18
# INFO : Acc:    13/18
# INFO : Cross-entropy: 16.039230346679688 nats (= perplexity 67342.5146910516)
# ---
# INFO : Gold:    This/D information/N was/V _OOV_/V from/I your/P own/J news/N stories/N on/I the/D region/N ./.
# INFO : Viterbi: This/D information/N was/V _OOV_/R from/I your/P own/J news/N stories/N on/I the/D region/N ./.
# INFO : Loss:    1/13
# INFO : Acc:    12/13
# INFO : Cross-entropy: 13.096787452697754 nats (= perplexity 8760.436595337365)
# ---
# INFO : Gold:    _OOV_/J _OOV_/J government/N _OOV_/N of/I the/D ``/` _OOV_/F ''/' was/V due/J to/T the/D drug/N _OOV_/N '/P history/N of/I _OOV_/V out/R _OOV_/N in/I the/D _OOV_/N ./.
# INFO : Viterbi: _OOV_/D _OOV_/J government/N _OOV_/, of/I the/D ``/` _OOV_/E ''/' was/V due/J to/T the/D drug/N _OOV_/I '/P history/N of/I _OOV_/D out/R _OOV_/V in/I the/D _OOV_/N ./.
# INFO : Loss:    6/25
# INFO : Acc:    19/25
# INFO : Cross-entropy: 29.614383697509766 nats (= perplexity 821897551.6762545)
# ---
# INFO : Gold:    Mary/N _OOV_/N Palo/N Alto/N ,/, Calif/N ./.
# INFO : Viterbi: Mary/N _OOV_/I Palo/N Alto/N ,/, Calif/N ./.
# INFO : Loss:    1/7
# INFO : Acc:    6/7
# INFO : Cross-entropy: 17.614578247070312 nats (= perplexity 200685.75274230217)
# ---
# INFO : Gold:    I/P suggest/V that/I The/D Wall/N Street/N Journal/N -LRB-/- as/R well/R as/I other/J U.S./N news/N publications/N of/I like/J mind/N -RRB-/- should/M put/V its/P money/N where/W its/P mouth/N is/V :/: _OOV_/V computer/N equipment/N to/T replace/V that/I damaged/V at/I El/N _OOV_/N ,/, buy/V ad/N space/N ,/, publish/V stories/N under/I the/D _OOV_/N of/I El/N _OOV_/N journalists/N ./.
# INFO : Viterbi: I/P suggest/V that/I The/D Wall/N Street/N Journal/N -LRB-/- as/R well/R as/I other/J U.S./N news/N publications/N of/I like/I mind/N -RRB-/- should/M put/V its/P money/N where/W its/P mouth/M is/V :/: _OOV_/D computer/N equipment/N to/T replace/V that/W damaged/V at/I El/N _OOV_/N ,/, buy/V ad/N space/N ,/, publish/V stories/N under/I the/D _OOV_/N of/I El/N _OOV_/I journalists/N ./.
# INFO : Loss:    5/53
# INFO : Acc:    48/53
# INFO : Cross-entropy: 15.704708099365234 nats (= perplexity 53405.791633508794)
# ---
# INFO : Gold:    Perhaps/R an/D arrangement/N could/M be/V worked/V out/R to/T ``/` sponsor/V ''/' El/N _OOV_/N journalists/N and/C staff/N by/I paying/V for/I added/V security/N in/I exchange/N for/I exclusive/J stories/N ./.
# INFO : Viterbi: Perhaps/R an/D arrangement/N could/M be/V worked/V out/R to/T ``/` sponsor/U ''/' El/N _OOV_/I journalists/N and/C staff/N by/I paying/V for/I added/J security/N in/I exchange/N for/I exclusive/J stories/N ./.
# INFO : Loss:    3/27
# INFO : Acc:    24/27
# INFO : Cross-entropy: 12.938546180725098 nats (= perplexity 7850.378544635438)
# ---
# INFO : Gold:    _OOV_/V El/N _OOV_/N 's/P courage/N with/I real/J support/N ./.
# INFO : Viterbi: _OOV_/D El/N _OOV_/I 's/P courage/N with/I real/J support/N ./.
# INFO : Loss:    2/9
# INFO : Acc:    7/9
# INFO : Cross-entropy: 22.36467933654785 nats (= perplexity 5400565.132127068)
# ---
# INFO : Gold:    Douglas/N B./N Evans/N
# INFO : Viterbi: Douglas/N B./N Evans/.
# INFO : Loss:    1/3
# INFO : Acc:    2/3
# INFO : Cross-entropy: 11.576026916503906 nats (= perplexity 3053.032064500592)
# ---

# %% [markdown]
# Make an HMM.  Let's do some pre-training to approximately maximize the
# regularized log-likelihood on supervised training data.  In other words, the
# probabilities at the M step will just be supervised count ratios.
#
# On each epoch, you will see two progress bars: first it collects counts from
# all the sentences (E step), and then after the M step, it evaluates the loss
# function, which is the (unregularized) cross-entropy on the training set.
#
# The parameters don't actually matter during the E step because there are no
# hidden tags to impute.  The first M step will jump right to the optimal
# solution.  The code will try a second epoch with the revised parameters, but
# the result will be identical, so it will detect convergence and stop.
#
# We arbitrarily choose λ=1 for our add-λ smoothing at the M step, but it would
# be better to search for the best value of this hyperparameter.

# %%
log.info("*** Hidden Markov Model (HMM)")
hmm = HiddenMarkovModel(entrain.tagset, entrain.vocab)  # randomly initialized parameters  
loss_sup = lambda model: model_cross_entropy(model, eval_corpus=ensup)
hmm.train(corpus=ensup, loss=loss_sup, λ=1.0,
          save_path="ensup_hmm.pkl")
# Out:
# INFO : *** Hidden Markov Model (HMM)
# 100%|██████████| 4051/4051 [00:10<00:00, 379.65it/s]
# INFO : Cross-entropy: 12.6436 nats (= perplexity 309772.928)
# 100%|██████████| 4051/4051 [00:26<00:00, 153.01it/s]
# 100%|██████████| 4051/4051 [00:10<00:00, 394.60it/s]
# INFO : Cross-entropy: 7.4503 nats (= perplexity 1720.380)
# 100%|██████████| 4051/4051 [00:25<00:00, 161.56it/s]
# 100%|██████████| 4051/4051 [00:10<00:00, 385.83it/s]
# INFO : Cross-entropy: 7.4503 nats (= perplexity 1720.402)
# INFO : Saved model to ensup_hmm.pkl

# %% [markdown]
# Now let's throw in the unsupervised training data as well, and continue
# training as before, in order to increase the regularized log-likelihood on
# this larger, semi-supervised training set.  It's now the *incomplete-data*
# log-likelihood.
#
# This time, we'll use a different evaluation loss function: we'll stop when the
# *tagging error rate* on a held-out dev set stops getting better.  Also, the
# implementation of this loss function (`viterbi_error_rate`) includes a helpful
# side effect: it logs the *cross-entropy* on the held-out dataset as well, just
# for your information.
#
# We hope that held-out tagging accuracy will go up for a little bit before it
# goes down again (see Merialdo 1994). (Log-likelihood on training data will
# continue to improve, and that improvement may generalize to held-out
# cross-entropy.  But getting accuracy to increase is harder.)

# %%
hmm = HiddenMarkovModel.load("ensup_hmm.pkl")  # reset to supervised model (in case you're re-executing this bit)
loss_dev = lambda model: viterbi_error_rate(model, eval_corpus=endev, 
                                            known_vocab=known_vocab)
hmm.train(corpus=entrain, loss=loss_dev, λ=1.0,
          save_path="entrain_hmm.pkl")
# Out:
# INFO : Loaded model from ensup_hmm.pkl
# 100%|██████████| 996/996 [00:03<00:00, 259.09it/s]
# INFO : Cross-entropy: 7.5993 nats (= perplexity 1996.796)
# 100%|██████████| 996/996 [00:05<00:00, 194.63it/s]
# INFO : Tagging accuracy: all: 88.663%, known: 93.059%, seen: 44.108%, novel: 42.734%
# 100%|██████████| 8064/8064 [01:04<00:00, 125.18it/s]
# 100%|██████████| 996/996 [00:03<00:00, 260.42it/s]
# INFO : Cross-entropy: 7.3485 nats (= perplexity 1553.850)
# 100%|██████████| 996/996 [00:04<00:00, 204.56it/s]
# INFO : Tagging accuracy: all: 87.031%, known: 91.397%, seen: 45.791%, novel: 40.225%
# INFO : Saved model to entrain_hmm.pkl

# %% [markdown]
# You can also retry the above workflow where you start with a worse supervised
# model (like Merialdo).  Does EM help more in that case?  It's easiest to rerun
# exactly the code above, but first make the `ensup` file smaller by copying
# `ensup-tiny` over it.  `ensup-tiny` is only 25 sentences (that happen to cover
# all tags in `endev`).  Back up your old `ensup` and your old `*.pkl` models
# before you do this.

# %% [markdown]
# More detailed look at the first 10 sentences in the held-out corpus,
# including Viterbi tagging.

# %%
def look_at_your_data(model, dev, N):
    for m, sentence in enumerate(dev):
        if m >= N: break
        viterbi = model.viterbi_tagging(sentence.desupervise(), endev)
        counts = eval_tagging(predicted=viterbi, gold=sentence, 
                              known_vocab=known_vocab)
        num = counts['NUM', 'ALL']
        denom = counts['DENOM', 'ALL']
        
        log.info(f"Gold:    {sentence}")
        log.info(f"Viterbi: {viterbi}")
        log.info(f"Loss:    {denom - num}/{denom}")
        log.info(f"Acc:    {num}/{denom}")
        xent = -model.logprob(sentence, endev) / len(sentence)  # measured in nats
        log.info(f"Cross-entropy: {xent/math.log(2)} nats (= perplexity {math.exp(xent)})\n---")

# %%
look_at_your_data(hmm, endev, 10)
# Out:
# INFO : Gold:    ``/` We/P 're/V strongly/R _OOV_/V that/I anyone/N who/W has/V eaten/V in/I the/D cafeteria/N this/D month/N have/V the/D shot/N ,/, ''/' Mr./N Mattausch/N added/V ,/, ``/` and/C that/D means/V virtually/R everyone/N who/W works/V here/R ./.
# INFO : Viterbi: ``/` We/P 're/V strongly/R _OOV_/V that/I anyone/N who/W has/V eaten/V in/I the/D cafeteria/N this/D month/N have/V the/D shot/N ,/, ''/' Mr./N Mattausch/T added/V ,/, ``/` and/C that/I means/V virtually/R everyone/, who/W works/V here/R ./.
# INFO : Loss:    3/34
# INFO : Cross-entropy: 10.61779499053955 nats (= perplexity 1571.3564102110174)
# ---
# INFO : Gold:    I/P was/V _OOV_/V to/T read/V the/D _OOV_/N of/I facts/N in/I your/P Oct./N 13/C editorial/N ``/` _OOV_/N 's/P _OOV_/N _OOV_/N ./. ''/'
# INFO : Viterbi: I/P was/V _OOV_/V to/T read/V the/D _OOV_/N of/I facts/N in/I your/P Oct./N 13/C editorial/, ``/` _OOV_/P 's/V _OOV_/D _OOV_/N ./. ''/'
# INFO : Loss:    4/21
# INFO : Cross-entropy: 10.876283645629883 nats (= perplexity 1879.6964241206033)
# ---
# INFO : Gold:    It/P is/V the/D _OOV_/J guerrillas/N who/W are/V aligned/V with/I the/D drug/N traffickers/N ,/, not/R the/D left/J _OOV_/N ./.
# INFO : Viterbi: It/P is/V the/D _OOV_/N guerrillas/, who/W are/V aligned/R with/I the/D drug/N traffickers/N ,/, not/R the/D left/J _OOV_/N ./.
# INFO : Loss:    3/18
# INFO : Cross-entropy: 9.650655746459961 nats (= perplexity 803.7794019158001)
# ---
# INFO : Gold:    This/D information/N was/V _OOV_/V from/I your/P own/J news/N stories/N on/I the/D region/N ./.
# INFO : Viterbi: This/D information/N was/V _OOV_/R from/I your/P own/J news/N stories/N on/I the/D region/N ./.
# INFO : Loss:    1/13
# INFO : Cross-entropy: 9.343284606933594 nats (= perplexity 649.5446827351528)
# ---
# INFO : Gold:    _OOV_/J _OOV_/J government/N _OOV_/N of/I the/D ``/` _OOV_/F ''/' was/V due/J to/T the/D drug/N _OOV_/N '/P history/N of/I _OOV_/V out/R _OOV_/N in/I the/D _OOV_/N ./.
# INFO : Viterbi: _OOV_/D _OOV_/J government/N _OOV_/N of/I the/D ``/N _OOV_/, ''/' was/V due/J to/T the/D drug/N _OOV_/I '/P history/N of/I _OOV_/N out/I _OOV_/N in/I the/D _OOV_/N ./.
# INFO : Loss:    6/25
# INFO : Cross-entropy: 10.9750394821167 nats (= perplexity 2012.8712164511169)
# ---
# INFO : Gold:    Mary/N _OOV_/N Palo/N Alto/N ,/, Calif/N ./.
# INFO : Viterbi: Mary/N _OOV_/I Palo/D Alto/N ,/, Calif/N ./.
# INFO : Loss:    2/7
# INFO : Cross-entropy: 10.526596069335938 nats (= perplexity 1475.0993990210206)
# ---
# INFO : Gold:    I/P suggest/V that/I The/D Wall/N Street/N Journal/N -LRB-/- as/R well/R as/I other/J U.S./N news/N publications/N of/I like/J mind/N -RRB-/- should/M put/V its/P money/N where/W its/P mouth/N is/V :/: _OOV_/V computer/N equipment/N to/T replace/V that/I damaged/V at/I El/N _OOV_/N ,/, buy/V ad/N space/N ,/, publish/V stories/N under/I the/D _OOV_/N of/I El/N _OOV_/N journalists/N ./.
# INFO : Viterbi: I/P suggest/V that/I The/D Wall/N Street/N Journal/N -LRB-/- as/I well/R as/I other/J U.S./N news/N publications/N of/I like/I mind/N -RRB-/N should/M put/V its/P money/N where/W its/P mouth/M is/V :/I _OOV_/D computer/N equipment/N to/T replace/V that/I damaged/N at/I El/D _OOV_/N ,/, buy/V ad/N space/N ,/, publish/V stories/N under/I the/D _OOV_/N of/I El/D _OOV_/J journalists/N ./.
# INFO : Loss:    10/53
# INFO : Cross-entropy: 11.649874687194824 nats (= perplexity 3213.3780363249007)
# ---
# INFO : Gold:    Perhaps/R an/D arrangement/N could/M be/V worked/V out/R to/T ``/` sponsor/V ''/' El/N _OOV_/N journalists/N and/C staff/N by/I paying/V for/I added/V security/N in/I exchange/N for/I exclusive/J stories/N ./.
# INFO : Viterbi: Perhaps/I an/D arrangement/N could/M be/V worked/V out/R to/T ``/` sponsor/F ''/' El/V _OOV_/T journalists/$ and/C staff/N by/I paying/V for/I added/J security/N in/I exchange/N for/I exclusive/J stories/N ./.
# INFO : Loss:    6/27
# INFO : Cross-entropy: 11.456055641174316 nats (= perplexity 2809.4189341157016)
# ---
# INFO : Gold:    _OOV_/V El/N _OOV_/N 's/P courage/N with/I real/J support/N ./.
# INFO : Viterbi: _OOV_/D El/N _OOV_/I 's/P courage/N with/I real/J support/N ./.
# INFO : Loss:    2/9
# INFO : Cross-entropy: 10.914258003234863 nats (= perplexity 1929.830500030177)
# ---
# INFO : Gold:    Douglas/N B./N Evans/N
# INFO : Viterbi: Douglas/D B./N Evans/.
# INFO : Loss:    2/3
# INFO : Cross-entropy: 11.67041015625 nats (= perplexity 3259.4429962987115)
# ---

# %% [markdown]
# Now let's try supervised training of a CRF (this doesn't use the unsupervised
# part of the data, so it is comparable to the supervised pre-training we did
# for the HMM).  We will use SGD to approximately maximize the regularized
# log-likelihood.
#
# As with the semi-supervised HMM training, we'll periodically evaluate the
# tagging accuracy (and also print the cross-entropy) on a held-out dev set.
# We use the default `eval_interval` and `tolerance`.  If you want to stop
# sooner, then you could increase the `tolerance` so the training method decides
# sooner that it has converged.
#
# We arbitrarily choose reg = 1.0 for L2 regularization, learning rate = 0.05,
# and a minibatch size of 10, but it would be better to search for the best
# value of these hyperparameters.
#
# Note that the logger reports the CRF's *conditional* cross-entropy, log p(tags
# | words) / n.  This is much lower than the HMM's *joint* cross-entropy log
# p(tags, words) / n, but that doesn't mean the CRF is worse at tagging.  The
# CRF is just predicting less information.

# %%
log.info("*** Conditional Random Field (CRF)\n")
crf = ConditionalRandomField(entrain.tagset, entrain.vocab)  # randomly initialized parameters  
crf.train(corpus=ensup, loss=loss_dev, reg=1.0, lr=0.05, minibatch_size=10,
          save_path="ensup_crf.pkl")
# Out:
# INFO : *** Conditional Random Field (CRF)
#
# 100%|██████████| 996/996 [00:05<00:00, 174.09it/s]
# INFO : Cross-entropy: 3.0490 nats (= perplexity 21.094)
# 100%|██████████| 996/996 [00:03<00:00, 308.86it/s]
# INFO : Tagging accuracy: all: 3.528%, known: 3.777%, seen: 3.199%, novel: 0.066%
# 100%|██████████| 500/500 [00:08<00:00, 58.41it/s]
# 100%|██████████| 996/996 [00:05<00:00, 196.12it/s]
# INFO : Cross-entropy: 0.9135 nats (= perplexity 2.493)
# 100%|██████████| 996/996 [00:02<00:00, 370.59it/s]
# INFO : Tagging accuracy: all: 70.938%, known: 71.787%, seen: 60.606%, novel: 62.748%
# 100%|██████████| 500/500 [00:05<00:00, 85.94it/s]
# 100%|██████████| 996/996 [00:03<00:00, 270.53it/s]
# INFO : Cross-entropy: 0.7452 nats (= perplexity 2.107)
# 100%|██████████| 996/996 [00:02<00:00, 351.75it/s]
# INFO : Tagging accuracy: all: 75.473%, known: 76.434%, seen: 63.300%, novel: 66.380%
# 100%|██████████| 500/500 [00:05<00:00, 89.79it/s]
# 100%|██████████| 996/996 [00:03<00:00, 303.23it/s]
# INFO : Cross-entropy: 0.6718 nats (= perplexity 1.958)
# 100%|██████████| 996/996 [00:02<00:00, 448.62it/s]
# INFO : Tagging accuracy: all: 80.659%, known: 82.130%, seen: 63.973%, novel: 65.984%
# 100%|██████████| 500/500 [00:05<00:00, 85.04it/s]
# 100%|██████████| 996/996 [00:03<00:00, 292.92it/s]
# INFO : Cross-entropy: 0.6083 nats (= perplexity 1.837)
# 100%|██████████| 996/996 [00:02<00:00, 357.59it/s]
# INFO : Tagging accuracy: all: 79.845%, known: 81.265%, seen: 62.963%, novel: 65.984%
# 100%|██████████| 500/500 [00:05<00:00, 88.24it/s]
# 100%|██████████| 996/996 [00:03<00:00, 311.75it/s]
# INFO : Cross-entropy: 0.5668 nats (= perplexity 1.763)
# 100%|██████████| 996/996 [00:02<00:00, 424.04it/s]
# INFO : Tagging accuracy: all: 80.989%, known: 82.501%, seen: 63.300%, novel: 66.116%
# 100%|██████████| 500/500 [00:05<00:00, 92.68it/s]
# 100%|██████████| 996/996 [00:03<00:00, 290.18it/s]
# INFO : Cross-entropy: 0.5330 nats (= perplexity 1.704)
# 100%|██████████| 996/996 [00:02<00:00, 405.53it/s]
# INFO : Tagging accuracy: all: 82.517%, known: 84.218%, seen: 62.963%, novel: 65.654%
# 100%|██████████| 500/500 [00:07<00:00, 64.52it/s]
# 100%|██████████| 996/996 [00:04<00:00, 243.01it/s]
# INFO : Cross-entropy: 0.5115 nats (= perplexity 1.668)
# 100%|██████████| 996/996 [00:03<00:00, 324.95it/s]
# INFO : Tagging accuracy: all: 83.916%, known: 85.779%, seen: 62.290%, novel: 65.522%
# 100%|██████████| 500/500 [00:07<00:00, 66.18it/s]
# 100%|██████████| 996/996 [00:03<00:00, 301.30it/s]
# INFO : Cross-entropy: 0.4923 nats (= perplexity 1.636)
# 100%|██████████| 996/996 [00:03<00:00, 328.88it/s]
# INFO : Tagging accuracy: all: 84.083%, known: 85.912%, seen: 64.141%, novel: 65.522%
# 100%|██████████| 500/500 [00:06<00:00, 75.20it/s]
# 100%|██████████| 996/996 [00:04<00:00, 208.44it/s]
# INFO : Cross-entropy: 0.4762 nats (= perplexity 1.610)
# 100%|██████████| 996/996 [00:02<00:00, 333.83it/s]
# INFO : Tagging accuracy: all: 83.711%, known: 85.459%, seen: 63.636%, novel: 66.380%
# 100%|██████████| 500/500 [00:07<00:00, 64.98it/s]
# 100%|██████████| 996/996 [00:04<00:00, 232.61it/s]
# INFO : Cross-entropy: 0.4589 nats (= perplexity 1.582)
# 100%|██████████| 996/996 [00:03<00:00, 312.97it/s]
# INFO : Tagging accuracy: all: 83.987%, known: 85.752%, seen: 63.636%, novel: 66.513%
# 100%|██████████| 500/500 [00:07<00:00, 65.61it/s]
# 100%|██████████| 996/996 [00:04<00:00, 238.74it/s]
# INFO : Cross-entropy: 0.4421 nats (= perplexity 1.556)
# 100%|██████████| 996/996 [00:02<00:00, 410.92it/s]
# INFO : Tagging accuracy: all: 84.780%, known: 86.686%, seen: 63.131%, novel: 65.786%
# 100%|██████████| 500/500 [00:05<00:00, 86.38it/s]
# 100%|██████████| 996/996 [00:04<00:00, 235.73it/s]
# INFO : Cross-entropy: 0.4349 nats (= perplexity 1.545)
# 100%|██████████| 996/996 [00:02<00:00, 336.77it/s]
# INFO : Tagging accuracy: all: 85.256%, known: 87.208%, seen: 62.963%, novel: 65.852%
# 100%|██████████| 500/500 [00:06<00:00, 80.83it/s]
# 100%|██████████| 996/996 [00:03<00:00, 266.23it/s]
# INFO : Cross-entropy: 0.4259 nats (= perplexity 1.531)
# 100%|██████████| 996/996 [00:02<00:00, 398.58it/s]
# INFO : Tagging accuracy: all: 85.185%, known: 87.139%, seen: 63.468%, novel: 65.522%
# 100%|██████████| 500/500 [00:06<00:00, 76.01it/s]
# 100%|██████████| 996/996 [00:03<00:00, 288.36it/s]
# INFO : Cross-entropy: 0.4143 nats (= perplexity 1.513)
# 100%|██████████| 996/996 [00:02<00:00, 375.62it/s]
# INFO : Tagging accuracy: all: 86.279%, known: 88.233%, seen: 63.805%, novel: 66.909%
# 100%|██████████| 500/500 [00:05<00:00, 89.97it/s]
# 100%|██████████| 996/996 [00:03<00:00, 313.84it/s]
# INFO : Cross-entropy: 0.4068 nats (= perplexity 1.502)
# 100%|██████████| 996/996 [00:02<00:00, 417.85it/s]
# INFO : Tagging accuracy: all: 86.338%, known: 88.325%, seen: 63.636%, novel: 66.579%
# 100%|██████████| 500/500 [00:05<00:00, 92.71it/s]
# 100%|██████████| 996/996 [00:03<00:00, 295.46it/s]
# INFO : Cross-entropy: 0.3985 nats (= perplexity 1.490)
# 100%|██████████| 996/996 [00:02<00:00, 421.47it/s]
# INFO : Tagging accuracy: all: 86.847%, known: 89.089%, seen: 63.131%, novel: 63.804%
# 100%|██████████| 500/500 [00:05<00:00, 92.29it/s]
# 100%|██████████| 996/996 [00:03<00:00, 311.33it/s]
# INFO : Cross-entropy: 0.3921 nats (= perplexity 1.480)
# 100%|██████████| 996/996 [00:02<00:00, 432.81it/s]
# INFO : Tagging accuracy: all: 87.035%, known: 89.126%, seen: 63.805%, novel: 65.984%
# 100%|██████████| 500/500 [00:05<00:00, 90.37it/s]
# 100%|██████████| 996/996 [00:03<00:00, 308.11it/s]
# INFO : Cross-entropy: 0.3832 nats (= perplexity 1.467)
# 100%|██████████| 996/996 [00:02<00:00, 412.97it/s]
# INFO : Tagging accuracy: all: 86.868%, known: 89.016%, seen: 62.963%, novel: 65.258%
# 100%|██████████| 500/500 [00:05<00:00, 90.96it/s]
# 100%|██████████| 996/996 [00:03<00:00, 309.41it/s]
# INFO : Cross-entropy: 0.3802 nats (= perplexity 1.463)
# 100%|██████████| 996/996 [00:02<00:00, 401.11it/s]
# INFO : Tagging accuracy: all: 87.745%, known: 89.909%, seen: 65.993%, novel: 65.059%
# 100%|██████████| 500/500 [00:05<00:00, 89.23it/s]
# 100%|██████████| 996/996 [00:03<00:00, 314.05it/s]
# INFO : Cross-entropy: 0.3737 nats (= perplexity 1.453)
# 100%|██████████| 996/996 [00:02<00:00, 434.26it/s]
# INFO : Tagging accuracy: all: 87.478%, known: 89.675%, seen: 63.300%, novel: 65.258%
# 100%|██████████| 500/500 [00:05<00:00, 91.44it/s]
# 100%|██████████| 996/996 [00:03<00:00, 311.59it/s]
# INFO : Cross-entropy: 0.3686 nats (= perplexity 1.446)
# 100%|██████████| 996/996 [00:02<00:00, 418.42it/s]
# INFO : Tagging accuracy: all: 87.528%, known: 89.749%, seen: 62.963%, novel: 65.125%
# 100%|██████████| 500/500 [00:05<00:00, 89.97it/s]
# 100%|██████████| 996/996 [00:03<00:00, 310.42it/s]
# INFO : Cross-entropy: 0.3637 nats (= perplexity 1.439)
# 100%|██████████| 996/996 [00:02<00:00, 424.61it/s]
# INFO : Tagging accuracy: all: 87.394%, known: 89.584%, seen: 62.963%, novel: 65.390%
# 100%|██████████| 500/500 [00:05<00:00, 84.74it/s]
# 100%|██████████| 996/996 [00:03<00:00, 297.59it/s]
# INFO : Cross-entropy: 0.3608 nats (= perplexity 1.434)
# 100%|██████████| 996/996 [00:02<00:00, 417.64it/s]
# INFO : Tagging accuracy: all: 87.670%, known: 90.055%, seen: 62.458%, novel: 63.144%
#  99%|█████████▊| 493/500 [00:05<00:00, 89.17it/s]INFO : Saved model to ensup_crf-12000.pkl
# 100%|██████████| 500/500 [00:05<00:00, 90.09it/s]
# 100%|██████████| 996/996 [00:03<00:00, 264.29it/s]
# INFO : Cross-entropy: 0.3536 nats (= perplexity 1.424)
# 100%|██████████| 996/996 [00:02<00:00, 342.71it/s]
# INFO : Tagging accuracy: all: 88.221%, known: 90.509%, seen: 62.795%, novel: 65.192%
# 100%|██████████| 500/500 [00:06<00:00, 79.55it/s]
# 100%|██████████| 996/996 [00:03<00:00, 279.77it/s]
# INFO : Cross-entropy: 0.3503 nats (= perplexity 1.419)
# 100%|██████████| 996/996 [00:02<00:00, 365.30it/s]
# INFO : Tagging accuracy: all: 87.895%, known: 90.248%, seen: 62.963%, novel: 63.738%
# 100%|██████████| 500/500 [00:06<00:00, 73.26it/s]
# 100%|██████████| 996/996 [00:03<00:00, 286.31it/s]
# INFO : Cross-entropy: 0.3464 nats (= perplexity 1.414)
# 100%|██████████| 996/996 [00:02<00:00, 399.26it/s]
# INFO : Tagging accuracy: all: 87.970%, known: 90.152%, seen: 62.795%, novel: 66.380%
# 100%|██████████| 500/500 [00:06<00:00, 83.17it/s]
# 100%|██████████| 996/996 [00:03<00:00, 261.47it/s]
# INFO : Cross-entropy: 0.3441 nats (= perplexity 1.411)
# 100%|██████████| 996/996 [00:02<00:00, 359.99it/s]
# INFO : Tagging accuracy: all: 88.814%, known: 91.159%, seen: 62.795%, novel: 65.192%
# 100%|██████████| 500/500 [00:05<00:00, 92.00it/s]
# 100%|██████████| 996/996 [00:03<00:00, 261.43it/s]
# INFO : Cross-entropy: 0.3420 nats (= perplexity 1.408)
# 100%|██████████| 996/996 [00:02<00:00, 387.25it/s]
# INFO : Tagging accuracy: all: 89.093%, known: 91.475%, seen: 63.131%, novel: 64.927%
# 100%|██████████| 500/500 [00:06<00:00, 75.22it/s]
# 100%|██████████| 996/996 [00:03<00:00, 292.09it/s]
# INFO : Cross-entropy: 0.3379 nats (= perplexity 1.402)
# 100%|██████████| 996/996 [00:03<00:00, 319.15it/s]
# INFO : Tagging accuracy: all: 88.187%, known: 90.399%, seen: 62.963%, novel: 66.182%
# 100%|██████████| 500/500 [00:05<00:00, 89.65it/s]
# 100%|██████████| 996/996 [00:03<00:00, 287.08it/s]
# INFO : Cross-entropy: 0.3373 nats (= perplexity 1.401)
# 100%|██████████| 996/996 [00:02<00:00, 373.22it/s]
# INFO : Tagging accuracy: all: 87.670%, known: 89.785%, seen: 63.300%, novel: 66.711%
# 100%|██████████| 500/500 [00:05<00:00, 91.97it/s]
# 100%|██████████| 996/996 [00:03<00:00, 327.71it/s]
# INFO : Cross-entropy: 0.3308 nats (= perplexity 1.392)
# 100%|██████████| 996/996 [00:02<00:00, 442.74it/s]
# INFO : Tagging accuracy: all: 88.613%, known: 90.921%, seen: 63.300%, novel: 65.258%
# 100%|██████████| 500/500 [00:05<00:00, 93.28it/s]
# 100%|██████████| 996/996 [00:03<00:00, 282.09it/s]
# INFO : Cross-entropy: 0.3311 nats (= perplexity 1.392)
# 100%|██████████| 996/996 [00:02<00:00, 406.25it/s]
# INFO : Tagging accuracy: all: 88.175%, known: 90.326%, seen: 64.141%, novel: 66.579%
# 100%|██████████| 500/500 [00:07<00:00, 65.36it/s]
# 100%|██████████| 996/996 [00:04<00:00, 220.20it/s]
# INFO : Cross-entropy: 0.3266 nats (= perplexity 1.386)
# 100%|██████████| 996/996 [00:02<00:00, 446.91it/s]
# INFO : Tagging accuracy: all: 89.081%, known: 91.447%, seen: 63.131%, novel: 65.125%
# 100%|██████████| 500/500 [00:05<00:00, 92.46it/s]
# 100%|██████████| 996/996 [00:03<00:00, 321.91it/s]
# INFO : Cross-entropy: 0.3230 nats (= perplexity 1.381)
# 100%|██████████| 996/996 [00:02<00:00, 443.64it/s]
# INFO : Tagging accuracy: all: 89.490%, known: 92.001%, seen: 62.458%, novel: 63.871%
# 100%|██████████| 500/500 [00:05<00:00, 96.76it/s]
# 100%|██████████| 996/996 [00:03<00:00, 319.55it/s]
# INFO : Cross-entropy: 0.3213 nats (= perplexity 1.379)
# 100%|██████████| 996/996 [00:02<00:00, 445.94it/s]
# INFO : Tagging accuracy: all: 88.668%, known: 90.857%, seen: 63.973%, novel: 66.777%
# 100%|██████████| 500/500 [00:05<00:00, 93.44it/s]
# 100%|██████████| 996/996 [00:03<00:00, 321.24it/s]
# INFO : Cross-entropy: 0.3185 nats (= perplexity 1.375)
# 100%|██████████| 996/996 [00:02<00:00, 445.56it/s]
# INFO : Tagging accuracy: all: 89.102%, known: 91.342%, seen: 64.141%, novel: 66.579%
# 100%|██████████| 500/500 [00:05<00:00, 93.93it/s]
# 100%|██████████| 996/996 [00:03<00:00, 321.69it/s]
# INFO : Cross-entropy: 0.3171 nats (= perplexity 1.373)
# 100%|██████████| 996/996 [00:02<00:00, 447.71it/s]
# INFO : Tagging accuracy: all: 90.087%, known: 92.326%, seen: 64.983%, novel: 67.635%
# 100%|██████████| 500/500 [00:05<00:00, 87.98it/s]
# 100%|██████████| 996/996 [00:03<00:00, 321.50it/s]
# INFO : Cross-entropy: 0.3132 nats (= perplexity 1.368)
# 100%|██████████| 996/996 [00:02<00:00, 440.01it/s]
# INFO : Tagging accuracy: all: 89.599%, known: 92.020%, seen: 62.458%, novel: 65.324%
# 100%|██████████| 500/500 [00:05<00:00, 92.15it/s]
# 100%|██████████| 996/996 [00:03<00:00, 317.85it/s]
# INFO : Cross-entropy: 0.3115 nats (= perplexity 1.365)
# 100%|██████████| 996/996 [00:02<00:00, 446.06it/s]
# INFO : Tagging accuracy: all: 89.432%, known: 91.768%, seen: 63.300%, novel: 65.984%
# 100%|██████████| 500/500 [00:05<00:00, 92.87it/s]
# 100%|██████████| 996/996 [00:03<00:00, 310.19it/s]
# INFO : Cross-entropy: 0.3118 nats (= perplexity 1.366)
# 100%|██████████| 996/996 [00:03<00:00, 323.25it/s]
# INFO : Tagging accuracy: all: 89.127%, known: 91.443%, seen: 63.805%, novel: 65.654%
# 100%|██████████| 500/500 [00:05<00:00, 90.80it/s]
# 100%|██████████| 996/996 [00:04<00:00, 239.80it/s]
# INFO : Cross-entropy: 0.3110 nats (= perplexity 1.365)
# 100%|██████████| 996/996 [00:02<00:00, 376.66it/s]
# INFO : Tagging accuracy: all: 89.620%, known: 92.010%, seen: 63.131%, novel: 65.522%
# 100%|██████████| 500/500 [00:05<00:00, 94.69it/s]
# 100%|██████████| 996/996 [00:03<00:00, 308.29it/s]
# INFO : Cross-entropy: 0.3054 nats (= perplexity 1.357)
# 100%|██████████| 996/996 [00:02<00:00, 444.16it/s]
# INFO : Tagging accuracy: all: 89.486%, known: 91.919%, seen: 62.626%, novel: 64.927%
# 100%|██████████| 500/500 [00:05<00:00, 95.96it/s]
# 100%|██████████| 996/996 [00:03<00:00, 313.40it/s]
# INFO : Cross-entropy: 0.3040 nats (= perplexity 1.355)
# 100%|██████████| 996/996 [00:02<00:00, 375.70it/s]
# INFO : Tagging accuracy: all: 90.046%, known: 92.496%, seen: 62.458%, novel: 65.522%
# 100%|██████████| 500/500 [00:05<00:00, 87.47it/s]
# 100%|██████████| 996/996 [00:03<00:00, 279.13it/s]
# INFO : Cross-entropy: 0.3020 nats (= perplexity 1.353)
# 100%|██████████| 996/996 [00:02<00:00, 341.58it/s]
# INFO : Tagging accuracy: all: 90.083%, known: 92.491%, seen: 62.795%, novel: 66.050%
# 100%|██████████| 500/500 [00:05<00:00, 92.23it/s]
# 100%|██████████| 996/996 [00:03<00:00, 321.01it/s]
# INFO : Cross-entropy: 0.3022 nats (= perplexity 1.353)
# 100%|██████████| 996/996 [00:02<00:00, 435.29it/s]
# INFO : Tagging accuracy: all: 90.405%, known: 92.674%, seen: 64.141%, novel: 67.966%
# 100%|██████████| 500/500 [00:05<00:00, 93.38it/s]
# 100%|██████████| 996/996 [00:03<00:00, 300.76it/s]
# INFO : Cross-entropy: 0.3033 nats (= perplexity 1.354)
# 100%|██████████| 996/996 [00:02<00:00, 407.22it/s]
# INFO : Tagging accuracy: all: 89.114%, known: 91.397%, seen: 62.795%, novel: 66.513%
# 100%|██████████| 500/500 [00:05<00:00, 90.44it/s]
# 100%|██████████| 996/996 [00:03<00:00, 316.01it/s]
# INFO : Cross-entropy: 0.2983 nats (= perplexity 1.348)
# 100%|██████████| 996/996 [00:02<00:00, 431.58it/s]
# INFO : Tagging accuracy: all: 90.167%, known: 92.500%, seen: 63.468%, novel: 66.975%
# 100%|██████████| 500/500 [00:05<00:00, 94.15it/s]
# 100%|██████████| 996/996 [00:03<00:00, 319.11it/s]
# INFO : Cross-entropy: 0.2969 nats (= perplexity 1.346)
# 100%|██████████| 996/996 [00:02<00:00, 446.98it/s]
# INFO : Tagging accuracy: all: 90.463%, known: 93.054%, seen: 62.963%, novel: 63.871%
# 100%|██████████| 500/500 [00:05<00:00, 95.81it/s]
# 100%|██████████| 996/996 [00:03<00:00, 322.71it/s]
# INFO : Cross-entropy: 0.2961 nats (= perplexity 1.345)
# 100%|██████████| 996/996 [00:02<00:00, 445.35it/s]
# INFO : Tagging accuracy: all: 90.229%, known: 92.716%, seen: 62.626%, novel: 65.192%
# 100%|██████████| 500/500 [00:05<00:00, 94.32it/s]
# 100%|██████████| 996/996 [00:03<00:00, 322.34it/s]
# INFO : Cross-entropy: 0.2944 nats (= perplexity 1.342)
# 100%|██████████| 996/996 [00:02<00:00, 445.47it/s]
# INFO : Tagging accuracy: all: 90.776%, known: 93.233%, seen: 62.795%, novel: 66.314%
#   1%|          | 6/500 [00:00<00:08, 59.57it/s]INFO : Saved model to ensup_crf-25010.pkl
# 100%|██████████| 500/500 [00:05<00:00, 94.80it/s]
# 100%|██████████| 996/996 [00:03<00:00, 322.27it/s]
# INFO : Cross-entropy: 0.2930 nats (= perplexity 1.340)
# 100%|██████████| 996/996 [00:02<00:00, 436.31it/s]
# INFO : Tagging accuracy: all: 90.292%, known: 92.560%, seen: 65.152%, novel: 67.437%
# 100%|██████████| 500/500 [00:05<00:00, 95.43it/s]
# 100%|██████████| 996/996 [00:03<00:00, 316.85it/s]
# INFO : Cross-entropy: 0.2918 nats (= perplexity 1.339)
# 100%|██████████| 996/996 [00:02<00:00, 446.14it/s]
# INFO : Tagging accuracy: all: 89.883%, known: 92.299%, seen: 63.131%, novel: 65.522%
# 100%|██████████| 500/500 [00:05<00:00, 96.38it/s]
# 100%|██████████| 996/996 [00:03<00:00, 321.64it/s]
# INFO : Cross-entropy: 0.2931 nats (= perplexity 1.341)
# 100%|██████████| 996/996 [00:02<00:00, 442.90it/s]
# INFO : Tagging accuracy: all: 90.020%, known: 92.386%, seen: 63.636%, novel: 66.248%
# 100%|██████████| 500/500 [00:05<00:00, 93.59it/s]
# 100%|██████████| 996/996 [00:03<00:00, 322.70it/s]
# INFO : Cross-entropy: 0.2887 nats (= perplexity 1.335)
# 100%|██████████| 996/996 [00:02<00:00, 436.64it/s]
# INFO : Tagging accuracy: all: 90.171%, known: 92.542%, seen: 62.795%, novel: 66.711%
# 100%|██████████| 500/500 [00:05<00:00, 95.66it/s]
# 100%|██████████| 996/996 [00:03<00:00, 315.07it/s]
# INFO : Cross-entropy: 0.2885 nats (= perplexity 1.334)
# 100%|██████████| 996/996 [00:02<00:00, 450.59it/s]
# INFO : Tagging accuracy: all: 90.567%, known: 93.022%, seen: 63.300%, novel: 65.852%
# 100%|██████████| 500/500 [00:05<00:00, 85.05it/s]
# 100%|██████████| 996/996 [00:04<00:00, 221.95it/s]
# INFO : Cross-entropy: 0.2862 nats (= perplexity 1.331)
# 100%|██████████| 996/996 [00:02<00:00, 406.56it/s]
# INFO : Tagging accuracy: all: 90.488%, known: 92.853%, seen: 63.131%, novel: 67.107%
# 100%|██████████| 500/500 [00:06<00:00, 71.84it/s]
# 100%|██████████| 996/996 [00:03<00:00, 254.89it/s]
# INFO : Cross-entropy: 0.2842 nats (= perplexity 1.329)
# 100%|██████████| 996/996 [00:07<00:00, 133.19it/s]
# INFO : Tagging accuracy: all: 90.684%, known: 93.118%, seen: 63.468%, novel: 66.248%
# 100%|██████████| 500/500 [00:10<00:00, 47.96it/s]
# 100%|██████████| 996/996 [00:03<00:00, 267.59it/s]
# INFO : Cross-entropy: 0.2831 nats (= perplexity 1.327)
# 100%|██████████| 996/996 [00:02<00:00, 352.42it/s]
# INFO : Tagging accuracy: all: 90.434%, known: 92.867%, seen: 62.626%, novel: 66.248%
# 100%|██████████| 500/500 [00:06<00:00, 79.01it/s]
# 100%|██████████| 996/996 [00:03<00:00, 256.26it/s]
# INFO : Cross-entropy: 0.2871 nats (= perplexity 1.333)
# 100%|██████████| 996/996 [00:02<00:00, 393.20it/s]
# INFO : Tagging accuracy: all: 90.780%, known: 93.302%, seen: 63.131%, novel: 65.258%
# 100%|██████████| 500/500 [00:05<00:00, 86.51it/s]
# 100%|██████████| 996/996 [00:03<00:00, 293.93it/s]
# INFO : Cross-entropy: 0.2848 nats (= perplexity 1.330)
# 100%|██████████| 996/996 [00:02<00:00, 402.98it/s]
# INFO : Tagging accuracy: all: 90.087%, known: 92.427%, seen: 63.468%, novel: 66.777%
# 100%|██████████| 500/500 [00:05<00:00, 91.72it/s]
# 100%|██████████| 996/996 [00:03<00:00, 301.89it/s]
# INFO : Cross-entropy: 0.2810 nats (= perplexity 1.324)
# 100%|██████████| 996/996 [00:02<00:00, 422.93it/s]
# INFO : Tagging accuracy: all: 90.530%, known: 92.954%, seen: 63.131%, novel: 66.314%
# 100%|██████████| 500/500 [00:05<00:00, 92.25it/s]
# 100%|██████████| 996/996 [00:03<00:00, 307.38it/s]
# INFO : Cross-entropy: 0.2824 nats (= perplexity 1.326)
# 100%|██████████| 996/996 [00:02<00:00, 363.57it/s]
# INFO : Tagging accuracy: all: 90.342%, known: 92.761%, seen: 63.973%, novel: 65.786%
# 100%|██████████| 500/500 [00:05<00:00, 92.35it/s]
# 100%|██████████| 996/996 [00:03<00:00, 288.98it/s]
# INFO : Cross-entropy: 0.2820 nats (= perplexity 1.326)
# 100%|██████████| 996/996 [00:02<00:00, 365.68it/s]
# INFO : Tagging accuracy: all: 91.194%, known: 93.682%, seen: 64.310%, novel: 65.852%
# 100%|██████████| 500/500 [00:05<00:00, 91.11it/s]
# 100%|██████████| 996/996 [00:03<00:00, 310.77it/s]
# INFO : Cross-entropy: 0.2786 nats (= perplexity 1.321)
# 100%|██████████| 996/996 [00:02<00:00, 397.39it/s]
# INFO : Tagging accuracy: all: 91.023%, known: 93.659%, seen: 62.963%, novel: 64.003%
# 100%|██████████| 500/500 [00:05<00:00, 84.23it/s]
# 100%|██████████| 996/996 [00:04<00:00, 217.85it/s]
# INFO : Cross-entropy: 0.2799 nats (= perplexity 1.323)
# 100%|██████████| 996/996 [00:02<00:00, 353.41it/s]
# INFO : Tagging accuracy: all: 91.144%, known: 93.769%, seen: 63.468%, novel: 64.135%
# 100%|██████████| 500/500 [00:05<00:00, 89.45it/s]
# 100%|██████████| 996/996 [00:03<00:00, 270.93it/s]
# INFO : Cross-entropy: 0.2768 nats (= perplexity 1.319)
# 100%|██████████| 996/996 [00:03<00:00, 265.96it/s]
# INFO : Tagging accuracy: all: 91.323%, known: 93.892%, seen: 62.963%, novel: 65.390%
# 100%|██████████| 500/500 [00:05<00:00, 88.93it/s]
# 100%|██████████| 996/996 [00:03<00:00, 281.19it/s]
# INFO : Cross-entropy: 0.2786 nats (= perplexity 1.321)
# 100%|██████████| 996/996 [00:02<00:00, 367.40it/s]
# INFO : Tagging accuracy: all: 90.488%, known: 92.926%, seen: 63.131%, novel: 66.050%
# 100%|██████████| 500/500 [00:08<00:00, 59.74it/s]
# 100%|██████████| 996/996 [00:03<00:00, 310.63it/s]
# INFO : Cross-entropy: 0.2751 nats (= perplexity 1.317)
# 100%|██████████| 996/996 [00:02<00:00, 397.24it/s]
# INFO : Tagging accuracy: all: 90.860%, known: 93.384%, seen: 62.626%, novel: 65.522%
# 100%|██████████| 500/500 [00:05<00:00, 89.38it/s]
# 100%|██████████| 996/996 [00:03<00:00, 312.96it/s]
# INFO : Cross-entropy: 0.2779 nats (= perplexity 1.320)
# 100%|██████████| 996/996 [00:02<00:00, 424.61it/s]
# INFO : Tagging accuracy: all: 90.492%, known: 92.770%, seen: 64.815%, novel: 67.701%
# 100%|██████████| 500/500 [00:06<00:00, 79.59it/s]
# 100%|██████████| 996/996 [00:04<00:00, 234.78it/s]
# INFO : Cross-entropy: 0.2740 nats (= perplexity 1.315)
# 100%|██████████| 996/996 [00:03<00:00, 274.74it/s]
# INFO : Tagging accuracy: all: 90.876%, known: 93.329%, seen: 63.300%, novel: 66.314%
# 100%|██████████| 500/500 [00:09<00:00, 50.55it/s]
# 100%|██████████| 996/996 [00:06<00:00, 154.82it/s]
# INFO : Cross-entropy: 0.2730 nats (= perplexity 1.314)
# 100%|██████████| 996/996 [00:04<00:00, 214.73it/s]
# INFO : Tagging accuracy: all: 91.106%, known: 93.567%, seen: 64.310%, novel: 66.116%
# 100%|██████████| 500/500 [00:07<00:00, 71.29it/s]
# 100%|██████████| 996/996 [00:04<00:00, 231.96it/s]
# INFO : Cross-entropy: 0.2732 nats (= perplexity 1.314)
# 100%|██████████| 996/996 [00:03<00:00, 315.60it/s]
# INFO : Tagging accuracy: all: 91.315%, known: 93.979%, seen: 63.131%, novel: 63.937%
# 100%|██████████| 500/500 [00:07<00:00, 67.14it/s]
# 100%|██████████| 996/996 [00:04<00:00, 220.81it/s]
# INFO : Cross-entropy: 0.2707 nats (= perplexity 1.311)
# 100%|██████████| 996/996 [00:03<00:00, 318.95it/s]
# INFO : Tagging accuracy: all: 91.202%, known: 93.718%, seen: 63.300%, novel: 65.852%
#  17%|█▋        | 83/500 [00:00<00:04, 95.86it/s]INFO : Saved model to ensup_crf-36590.pkl
# 100%|██████████| 500/500 [00:05<00:00, 92.22it/s]
# 100%|██████████| 996/996 [00:03<00:00, 312.39it/s]
# INFO : Cross-entropy: 0.2716 nats (= perplexity 1.312)
# 100%|██████████| 996/996 [00:02<00:00, 435.88it/s]
# INFO : Tagging accuracy: all: 91.052%, known: 93.695%, seen: 63.131%, novel: 63.871%
# 100%|██████████| 500/500 [00:05<00:00, 90.96it/s]
# 100%|██████████| 996/996 [00:03<00:00, 310.64it/s]
# INFO : Cross-entropy: 0.2703 nats (= perplexity 1.310)
# 100%|██████████| 996/996 [00:02<00:00, 434.25it/s]
# INFO : Tagging accuracy: all: 91.261%, known: 93.640%, seen: 64.141%, novel: 67.569%
# 100%|██████████| 500/500 [00:05<00:00, 90.76it/s]
# 100%|██████████| 996/996 [00:03<00:00, 311.17it/s]
# INFO : Cross-entropy: 0.2708 nats (= perplexity 1.311)
# 100%|██████████| 996/996 [00:02<00:00, 426.79it/s]
# INFO : Tagging accuracy: all: 90.651%, known: 93.118%, seen: 62.121%, novel: 66.248%
# 100%|██████████| 500/500 [00:05<00:00, 93.15it/s]
# 100%|██████████| 996/996 [00:03<00:00, 309.36it/s]
# INFO : Cross-entropy: 0.2705 nats (= perplexity 1.311)
# 100%|██████████| 996/996 [00:02<00:00, 432.56it/s]
# INFO : Tagging accuracy: all: 91.448%, known: 94.075%, seen: 63.468%, novel: 64.531%
# 100%|██████████| 500/500 [00:05<00:00, 90.57it/s]
# 100%|██████████| 996/996 [00:03<00:00, 264.80it/s]
# INFO : Cross-entropy: 0.2690 nats (= perplexity 1.309)
# 100%|██████████| 996/996 [00:02<00:00, 381.59it/s]
# INFO : Tagging accuracy: all: 91.043%, known: 93.672%, seen: 63.131%, novel: 64.069%
# 100%|██████████| 500/500 [00:05<00:00, 92.27it/s]
# 100%|██████████| 996/996 [00:03<00:00, 307.39it/s]
# INFO : Cross-entropy: 0.2700 nats (= perplexity 1.310)
# 100%|██████████| 996/996 [00:02<00:00, 420.66it/s]
# INFO : Tagging accuracy: all: 90.643%, known: 93.022%, seen: 63.636%, novel: 66.909%
# 100%|██████████| 500/500 [00:05<00:00, 94.03it/s]
# 100%|██████████| 996/996 [00:03<00:00, 314.29it/s]
# INFO : Cross-entropy: 0.2676 nats (= perplexity 1.307)
# 100%|██████████| 996/996 [00:02<00:00, 394.32it/s]
# INFO : Tagging accuracy: all: 91.043%, known: 93.444%, seen: 65.320%, novel: 66.513%
# 100%|██████████| 500/500 [00:05<00:00, 92.00it/s]
# 100%|██████████| 996/996 [00:03<00:00, 303.46it/s]
# INFO : Cross-entropy: 0.2672 nats (= perplexity 1.306)
# 100%|██████████| 996/996 [00:03<00:00, 330.36it/s]
# INFO : Tagging accuracy: all: 90.864%, known: 93.324%, seen: 62.626%, novel: 66.446%
# 100%|██████████| 500/500 [00:05<00:00, 84.46it/s]
# 100%|██████████| 996/996 [00:03<00:00, 304.74it/s]
# INFO : Cross-entropy: 0.2657 nats (= perplexity 1.304)
# 100%|██████████| 996/996 [00:02<00:00, 398.90it/s]
# INFO : Tagging accuracy: all: 91.110%, known: 93.531%, seen: 63.805%, novel: 66.909%
# 100%|██████████| 500/500 [00:05<00:00, 92.91it/s]
# 100%|██████████| 996/996 [00:03<00:00, 268.36it/s]
# INFO : Cross-entropy: 0.2660 nats (= perplexity 1.305)
# 100%|██████████| 996/996 [00:02<00:00, 431.38it/s]
# INFO : Tagging accuracy: all: 90.964%, known: 93.439%, seen: 63.131%, novel: 66.182%
# 100%|██████████| 500/500 [00:05<00:00, 92.22it/s]
# 100%|██████████| 996/996 [00:03<00:00, 310.48it/s]
# INFO : Cross-entropy: 0.2670 nats (= perplexity 1.306)
# 100%|██████████| 996/996 [00:02<00:00, 433.03it/s]
# INFO : Tagging accuracy: all: 91.570%, known: 94.236%, seen: 63.973%, novel: 63.937%
# 100%|██████████| 500/500 [00:05<00:00, 94.38it/s]
# 100%|██████████| 996/996 [00:03<00:00, 313.43it/s]
# INFO : Cross-entropy: 0.2643 nats (= perplexity 1.302)
# 100%|██████████| 996/996 [00:02<00:00, 434.50it/s]
# INFO : Tagging accuracy: all: 91.169%, known: 93.654%, seen: 63.636%, novel: 66.116%
# 100%|██████████| 500/500 [00:05<00:00, 92.32it/s]
# 100%|██████████| 996/996 [00:03<00:00, 300.83it/s]
# INFO : Cross-entropy: 0.2641 nats (= perplexity 1.302)
# 100%|██████████| 996/996 [00:02<00:00, 431.28it/s]
# INFO : Tagging accuracy: all: 91.123%, known: 93.544%, seen: 63.468%, novel: 67.041%
# 100%|██████████| 500/500 [00:05<00:00, 92.58it/s]
# 100%|██████████| 996/996 [00:03<00:00, 314.69it/s]
# INFO : Cross-entropy: 0.2648 nats (= perplexity 1.303)
# 100%|██████████| 996/996 [00:02<00:00, 425.38it/s]
# INFO : Tagging accuracy: all: 91.114%, known: 93.531%, seen: 63.636%, novel: 67.041%
# 100%|██████████| 500/500 [00:05<00:00, 91.83it/s]
# 100%|██████████| 996/996 [00:03<00:00, 314.92it/s]
# INFO : Cross-entropy: 0.2636 nats (= perplexity 1.302)
# 100%|██████████| 996/996 [00:02<00:00, 426.19it/s]
# INFO : Tagging accuracy: all: 91.323%, known: 93.988%, seen: 63.300%, novel: 63.871%
# 100%|██████████| 500/500 [00:05<00:00, 94.38it/s]
# 100%|██████████| 996/996 [00:03<00:00, 289.92it/s]
# INFO : Cross-entropy: 0.2625 nats (= perplexity 1.300)
# 100%|██████████| 996/996 [00:02<00:00, 369.73it/s]
# INFO : Tagging accuracy: all: 91.503%, known: 94.020%, seen: 63.973%, novel: 65.984%
# 100%|██████████| 500/500 [00:05<00:00, 85.51it/s]
# 100%|██████████| 996/996 [00:03<00:00, 310.08it/s]
# INFO : Cross-entropy: 0.2633 nats (= perplexity 1.301)
# 100%|██████████| 996/996 [00:02<00:00, 414.27it/s]
# INFO : Tagging accuracy: all: 91.236%, known: 93.709%, seen: 64.141%, novel: 66.182%
# 100%|██████████| 500/500 [00:05<00:00, 90.07it/s]
# 100%|██████████| 996/996 [00:03<00:00, 302.12it/s]
# INFO : Cross-entropy: 0.2611 nats (= perplexity 1.298)
# 100%|██████████| 996/996 [00:02<00:00, 405.52it/s]
# INFO : Tagging accuracy: all: 91.595%, known: 94.107%, seen: 63.468%, novel: 66.380%
# 100%|██████████| 500/500 [00:05<00:00, 89.17it/s]
# 100%|██████████| 996/996 [00:03<00:00, 288.66it/s]
# INFO : Cross-entropy: 0.2613 nats (= perplexity 1.299)
# 100%|██████████| 996/996 [00:02<00:00, 421.85it/s]
# INFO : Tagging accuracy: all: 91.256%, known: 93.759%, seen: 63.300%, novel: 66.116%
# 100%|██████████| 500/500 [00:05<00:00, 92.62it/s]
# 100%|██████████| 996/996 [00:03<00:00, 308.25it/s]
# INFO : Cross-entropy: 0.2602 nats (= perplexity 1.297)
# 100%|██████████| 996/996 [00:02<00:00, 403.29it/s]
# INFO : Tagging accuracy: all: 91.319%, known: 93.865%, seen: 62.963%, novel: 65.720%
# 100%|██████████| 500/500 [00:05<00:00, 90.92it/s]
# 100%|██████████| 996/996 [00:03<00:00, 298.51it/s]
# INFO : Cross-entropy: 0.2595 nats (= perplexity 1.296)
# 100%|██████████| 996/996 [00:02<00:00, 422.47it/s]
# INFO : Tagging accuracy: all: 91.753%, known: 94.451%, seen: 62.963%, novel: 64.135%
# 100%|██████████| 500/500 [00:05<00:00, 84.60it/s]
# 100%|██████████| 996/996 [00:03<00:00, 312.27it/s]
# INFO : Cross-entropy: 0.2610 nats (= perplexity 1.298)
# 100%|██████████| 996/996 [00:02<00:00, 406.22it/s]
# INFO : Tagging accuracy: all: 91.148%, known: 93.640%, seen: 63.300%, novel: 66.116%
# 100%|██████████| 500/500 [00:05<00:00, 91.73it/s]
# 100%|██████████| 996/996 [00:03<00:00, 293.36it/s]
# INFO : Cross-entropy: 0.2597 nats (= perplexity 1.297)
# 100%|██████████| 996/996 [00:02<00:00, 378.56it/s]
# INFO : Tagging accuracy: all: 91.511%, known: 93.956%, seen: 65.152%, novel: 66.579%
# 100%|██████████| 500/500 [00:05<00:00, 90.97it/s]
# 100%|██████████| 996/996 [00:03<00:00, 293.76it/s]
# INFO : Cross-entropy: 0.2589 nats (= perplexity 1.296)
# 100%|██████████| 996/996 [00:02<00:00, 410.14it/s]
# INFO : Tagging accuracy: all: 91.720%, known: 94.382%, seen: 63.468%, novel: 64.399%
# 100%|██████████| 500/500 [00:05<00:00, 90.66it/s]
# 100%|██████████| 996/996 [00:03<00:00, 270.24it/s]
# INFO : Cross-entropy: 0.2633 nats (= perplexity 1.301)
# 100%|██████████| 996/996 [00:02<00:00, 390.20it/s]
# INFO : Tagging accuracy: all: 90.780%, known: 93.169%, seen: 64.141%, novel: 66.777%
# 100%|██████████| 500/500 [00:05<00:00, 93.07it/s]
# 100%|██████████| 996/996 [00:03<00:00, 299.81it/s]
# INFO : Cross-entropy: 0.2574 nats (= perplexity 1.294)
# 100%|██████████| 996/996 [00:02<00:00, 397.42it/s]
# INFO : Tagging accuracy: all: 92.008%, known: 94.561%, seen: 64.310%, novel: 66.050%
# 100%|██████████| 500/500 [00:05<00:00, 90.75it/s]
# 100%|██████████| 996/996 [00:03<00:00, 308.57it/s]
# INFO : Cross-entropy: 0.2598 nats (= perplexity 1.297)
# 100%|██████████| 996/996 [00:02<00:00, 409.18it/s]
# INFO : Tagging accuracy: all: 91.185%, known: 93.613%, seen: 63.973%, novel: 66.843%
# INFO : Saved model to ensup_crf.pkl

# %%
crf = HiddenMarkovModel.load("ensup_crf.pkl")  # reset to supervised model (in case you're re-executing this bit)
loss_dev = lambda model: viterbi_error_rate(model, eval_corpus=endev, 
                                            known_vocab=known_vocab)
crf.train(corpus=entrain, loss=loss_dev,
          save_path="entrain_crf_raw.pkl", eval_interval=5000, max_steps=10000)
# Out:
# INFO : Loaded model from ensup_crf.pkl
# 100%|██████████| 996/996 [00:04<00:00, 223.45it/s]
# INFO : Cross-entropy: 0.2598 nats (= perplexity 1.297)
# 100%|██████████| 996/996 [00:02<00:00, 342.96it/s]
# INFO : Tagging accuracy: all: 91.185%, known: 93.613%, seen: 63.973%, novel: 66.843%
# 100%|██████████| 5000/5000 [01:50<00:00, 45.36it/s]
# 100%|██████████| 996/996 [00:04<00:00, 227.48it/s]
# INFO : Cross-entropy: 0.2465 nats (= perplexity 1.280)
# 100%|██████████| 996/996 [00:02<00:00, 338.98it/s]
# INFO : Tagging accuracy: all: 91.624%, known: 94.263%, seen: 63.636%, novel: 64.531%
# 100%|██████████| 5000/5000 [01:27<00:00, 57.03it/s]
# 100%|██████████| 996/996 [00:02<00:00, 334.48it/s]
# INFO : Cross-entropy: 0.2372 nats (= perplexity 1.268)
# 100%|██████████| 996/996 [00:02<00:00, 473.23it/s]
# INFO : Tagging accuracy: all: 91.799%, known: 94.469%, seen: 62.290%, novel: 64.861%
# INFO : Saved model to entrain_crf_raw.pkl

# %% [markdown]
# Let's examine how the CRF does on individual sentences.
# (Do you see any error patterns here that would inspire additional CRF features?)

# %%
look_at_your_data(crf, endev, 10)

# %%
# Out:
# INFO : Loaded model from ../code/models/en_hmm_awesome.pkl
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[20], line 18
#      15         xent = -model.logprob(sentence, endev) / len(sentence)  # measured in nats
#      16         log.info(f"Cross-entropy: {xent/math.log(2)} nats (= perplexity {math.exp(xent)})\n---")
# ---> 18 look_at_your_data_posterior(hmm, endev, 10)
#
# Cell In[20], line 6, in look_at_your_data_posterior(model, dev, N)
#       4 for m, sentence in enumerate(dev):
#       5     if m >= N: break
# ----> 6     posterior = model.posterior_decode(sentence.desupervise(), endev)
#       7     counts = eval_tagging(predicted=posterior, gold=sentence,
#       8                           known_vocab=known_vocab)
#       9     num = counts['NUM', 'ALL']
#
# File ~/Desktop/hw-tag/code/hmm.py:578, in HiddenMarkovModel.posterior_decode(self, sentence, corpus)
#     575 assert torch.isclose(log_Z, log_Z_bwd)
#     577 log_alpha = self._log_alpha
# --> 578 log_beta  = self._log_beta
#     580 tags: List[int] = [self.bos_t] + [0]*(n-2) + [self.eos_t]
#     581 for j in range(1, n-1):  # 非BOS/非EOS
#
# AttributeError: 'HiddenMarkovModel' object has no attribute '_log_beta'
