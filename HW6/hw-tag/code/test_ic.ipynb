# %%
#!/usr/bin/env python3

# %% [markdown]
# This file illustrates how you might experiment with the HMM interface.
# You can paste these commands in at the Python prompt, or execute `test_ic.py` directly.
# A notebook interface is nicer than the plain Python prompt, so we provide
# a notebook version of this file as `test_ic.ipynb`, which you can open with
# `jupyter` or with Visual Studio `code` (run it with the `nlp-class` kernel).

# %%
import logging, math, os
from pathlib import Path

# %%
import torch
from torch import tensor

# %%
import os
print(os.getcwd())  
print(os.listdir())
# Out:
# /Users/lhyyyh/Desktop/JHU-601.665-NLP-2025-Fall-Homework/HW6/hw-tag/code
# ['en_crf.pkl', 'en_hmm_raw.pkl', 'en_hmm.pkl', 'test_ic.ipynb', 'crf.py', 'nlp-class.yml', 'models', 'scripts.txt', '__pycache__', 'trial.ipynb', 'results', 'test_en.ipynb', 'INSTRUCTIONS.html', 'integerize.py', 'test_en.py', 'try.ipynb', 'eval.py', 'INSTRUCTIONS.md', 'test_ic.py', 'tag.py', 'corpus.py', 'hmm.py']

# %%
from corpus import TaggedCorpus
from eval import model_cross_entropy, write_tagging
from hmm import HiddenMarkovModel
from crf import ConditionalRandomField

# %% [markdown]
# Set up logging.

# %%
log = logging.getLogger("test_ic")       # For usage, see findsim.py in earlier assignment.
logging.root.setLevel(level=logging.INFO)
logging.basicConfig(level=logging.INFO)  # could change INFO to DEBUG
# torch.autograd.set_detect_anomaly(True)    # uncomment to improve error messages from .backward(), but slows down

# %% [markdown]
# Switch working directory to the directory where the data live.  You may want to edit this line.

# %%
os.chdir("../data")

# %% [markdown]
# Get vocabulary and tagset from a supervised corpus.

# %%
icsup = TaggedCorpus(Path("icsup"), add_oov=False)
log.info(f"Ice cream vocabulary: {list(icsup.vocab)}")
log.info(f"Ice cream tagset: {list(icsup.tagset)}")
# Out:
# INFO:corpus:Read 40 tokens from icsup
# INFO:corpus:Created 4 tag types
# INFO:corpus:Created 5 word types
# INFO:test_ic:Ice cream vocabulary: ['1', '2', '3', '_EOS_WORD_', '_BOS_WORD_']
# INFO:test_ic:Ice cream tagset: ['C', 'H', '_EOS_TAG_', '_BOS_TAG_']

# %% [markdown]
# Two ways to look at the corpus ...

# %%
os.system("cat icsup")   # call the shell to look at the file directly
# Out:
# 1/C 1/C 1/C 1/C 1/C 1/C 1/C 2/C 2/C 3/H
# 1/H 2/H 2/H 3/H 3/H 3/H 3/H 3/H 3/H 3/C
# 1/C 1/C 1/C 1/C 1/C 1/C 1/C 2/C 2/C 3/H
# 1/H 2/H 2/H 3/H 3/H 3/H 3/H 3/H 3/H 3/C
# 0

# %%
log.info(icsup)          # print the TaggedCorpus python object we constructed from it
# Out:
# INFO:test_ic:1/C 1/C 1/C 1/C 1/C 1/C 1/C 2/C 2/C 3/H
# 1/H 2/H 2/H 3/H 3/H 3/H 3/H 3/H 3/H 3/C
# 1/C 1/C 1/C 1/C 1/C 1/C 1/C 2/C 2/C 3/H
# 1/H 2/H 2/H 3/H 3/H 3/H 3/H 3/H 3/H 3/C

# %% [markdown]
# Make an HMM.

# %%
log.info("*** Hidden Markov Model (HMM) test\n")
hmm = HiddenMarkovModel(icsup.tagset, icsup.vocab)
# Change the transition/emission initial probabilities to match the ice cream spreadsheet,
# and test your implementation of the Viterbi algorithm.  Note that the spreadsheet 
# uses transposed versions of these matrices.
hmm.B = tensor([[0.7000, 0.2000, 0.1000],    # emission probabilities
                [0.1000, 0.2000, 0.7000],
                [0.0000, 0.0000, 0.0000],
                [0.0000, 0.0000, 0.0000]])
hmm.A = tensor([[0.8000, 0.1000, 0.1000, 0.0000],   # transition probabilities
                [0.1000, 0.8000, 0.1000, 0.0000],
                [0.0000, 0.0000, 0.0000, 0.0000],
                [0.5000, 0.5000, 0.0000, 0.0000]])
log.info("*** Current A, B matrices (using initalizations from the ice cream spreadsheet)")
hmm.printAB()
# Out:
# INFO:test_ic:*** Hidden Markov Model (HMM) test
#
# INFO:test_ic:*** Current A, B matrices (using initalizations from the ice cream spreadsheet)
# Transition matrix A:
# 	C	H	_EOS_TAG_	_BOS_TAG_
# C	0.800	0.100	0.100	0.000
# H	0.100	0.800	0.100	0.000
# _EOS_TAG_	0.000	0.000	0.000	0.000
# _BOS_TAG_	0.500	0.500	0.000	0.000
#
# Emission matrix B:
# 	1	2	3
# C	0.700	0.200	0.100
# H	0.100	0.200	0.700
# _EOS_TAG_	0.000	0.000	0.000
# _BOS_TAG_	0.000	0.000	0.000

# %% [markdown]
# Try it out on the raw data from the spreadsheet, available in `icraw``.

# %%
log.info("*** Viterbi results on icraw with hard coded parameters")
icraw = TaggedCorpus(Path("icraw"), tagset=icsup.tagset, vocab=icsup.vocab)
write_tagging(hmm, icraw, Path("icraw_hmm.output"))  # calls hmm.viterbi_tagging on each sentence
os.system("cat icraw_hmm.output")   # print the file we just created
# Out:
# INFO:test_ic:*** Viterbi results on icraw with hard coded parameters
# 100%|██████████| 1/1 [00:00<00:00, 632.63it/s]
# 2/H 3/H 3/H 2/H 3/H 2/H 3/H 2/H 2/H 3/H 1/H 3/H 3/H 1/C 1/C 1/C 2/C 1/C 1/C 1/C 3/C 1/C 2/C 1/C 1/C 1/C 2/H 3/H 3/H 2/H 3/H 2/H 2/H
# 0

# %% [markdown]
# Did the parameters that we guessed above get the "correct" answer,
# as revealed in `icdev`?

# %%
icdev = TaggedCorpus(Path("icdev"), tagset=icsup.tagset, vocab=icsup.vocab)
log.info(f"*** Compare to icdev corpus:\n{icdev}")
from eval import viterbi_error_rate
viterbi_error_rate(hmm, icdev, show_cross_entropy=False)
# Out:
# INFO:test_ic:*** Compare to icdev corpus:
# 2/H 3/H 3/H 2/H 3/H 2/H 3/H 2/H 2/H 3/H 1/C 3/C 3/C 1/C 1/C 1/C 2/C 1/C 1/C 1/C 3/C 1/C 2/C 1/C 1/C 1/C 2/H 3/H 3/H 2/H 3/H 2/H 2/H
# 100%|██████████| 1/1 [00:00<00:00, 618.08it/s]
# INFO:eval:Tagging accuracy: all: 90.909%, seen: 90.909%, novel: nan%
# 0.09090909090909094

# %% [markdown]
# Now let's try your training code, running it on supervised data.
# To test this, we'll restart from a random initialization.
# (You could also try creating this new model with `unigram=true`,
# which will affect the rest of the notebook.)

# %%
hmm = HiddenMarkovModel(icsup.tagset, icsup.vocab)
log.info("*** A, B matrices as randomly initialized close to uniform")
hmm.printAB()
# Out:
# INFO:test_ic:*** A, B matrices as randomly initialized close to uniform
# Transition matrix A:
# 	C	H	_EOS_TAG_	_BOS_TAG_
# C	0.334	0.334	0.332	0.000
# H	0.334	0.332	0.334	0.000
# _EOS_TAG_	0.334	0.333	0.333	0.000
# _BOS_TAG_	0.333	0.334	0.334	0.000
#
# Emission matrix B:
# 	1	2	3
# C	0.333	0.335	0.332
# H	0.333	0.333	0.334
# _EOS_TAG_	0.000	0.000	0.000
# _BOS_TAG_	0.000	0.000	0.000

# %%
log.info("*** Supervised HMM training on icsup")
cross_entropy_loss = lambda model: model_cross_entropy(model, icsup)
hmm.train(corpus=icsup, loss=cross_entropy_loss, tolerance=0.0001)
log.info("*** A, B matrices after training on icsup (should "
         "match initial params on spreadsheet [transposed])")
hmm.printAB()
# Out:
# INFO:test_ic:*** Supervised HMM training on icsup
# 100%|██████████| 4/4 [00:00<00:00, 1440.97it/s]
# INFO:eval:Cross-entropy: 2.0979 nats (= perplexity 8.149)
# 100%|██████████| 4/4 [00:00<00:00, 963.60it/s]
# 100%|██████████| 4/4 [00:00<00:00, 1638.08it/s]
# INFO:eval:Cross-entropy: 1.3729 nats (= perplexity 3.947)
# 100%|██████████| 4/4 [00:00<00:00, 1067.05it/s]
# 100%|██████████| 4/4 [00:00<00:00, 2128.55it/s]
# INFO:eval:Cross-entropy: 1.3729 nats (= perplexity 3.947)
# INFO:hmm:Saved model to my_hmm.pkl
# INFO:test_ic:*** A, B matrices after training on icsup (should match initial params on spreadsheet [transposed])
# Transition matrix A:
# 	C	H	_EOS_TAG_	_BOS_TAG_
# C	0.800	0.100	0.100	0.000
# H	0.100	0.800	0.100	0.000
# _EOS_TAG_	0.000	0.000	0.000	0.000
# _BOS_TAG_	0.500	0.500	0.000	0.000
#
# Emission matrix B:
# 	1	2	3
# C	0.700	0.200	0.100
# H	0.100	0.200	0.700
# _EOS_TAG_	0.000	0.000	0.000
# _BOS_TAG_	0.000	0.000	0.000

# %% [markdown]
# Now that we've reached the spreadsheet's starting guess, let's again tag
# the spreadsheet "sentence" (that is, the sequence of ice creams) using the
# Viterbi algorithm.

# %%
log.info("*** Viterbi results on icraw")
icraw = TaggedCorpus(Path("icraw"), tagset=icsup.tagset, vocab=icsup.vocab)
write_tagging(hmm, icraw, Path("icraw_hmm.output"))  # calls hmm.viterbi_tagging on each sentence
os.system("cat icraw_hmm.output")   # print the file we just created
# Out:
# INFO:test_ic:*** Viterbi results on icraw
# 100%|██████████| 1/1 [00:00<00:00, 533.90it/s]
# 2/H 3/H 3/H 2/H 3/H 2/H 3/H 2/H 2/H 3/H 1/H 3/H 3/H 1/C 1/C 1/C 2/C 1/C 1/C 1/C 3/C 1/C 2/C 1/C 1/C 1/C 2/C 3/H 3/H 2/H 3/H 2/H 2/H
# 0

# %% [markdown]
# Next let's use the forward algorithm to see what the model thinks about
# the probability of the spreadsheet "sentence."

# %%
log.info("*** Forward algorithm on icraw (should approximately match iteration 0 "
             "on spreadsheet)")
for sentence in icraw:
    prob = math.exp(hmm.logprob(sentence, icraw))
    log.info(f"{prob} = p({sentence})")
# Out:
# INFO:test_ic:*** Forward algorithm on icraw (should approximately match iteration 0 on spreadsheet)
# INFO:test_ic:9.12758979993639e-19 = p(2 3 3 2 3 2 3 2 2 3 1 3 3 1 1 1 2 1 1 1 3 1 2 1 1 1 2 3 3 2 3 2 2)

# %% [markdown]
# Finally, let's reestimate on the icraw data, as the spreadsheet does.
# We'll evaluate as we go along on the *training* perplexity, and stop
# when that has more or less converged.

# %%
log.info("*** Reestimating on icraw (perplexity should improve on every iteration)")
negative_log_likelihood = lambda model: model_cross_entropy(model, icraw)  # evaluate on icraw itself
hmm.train(corpus=icraw, loss=negative_log_likelihood, tolerance=0.0001)
# Out:
# INFO:test_ic:*** Reestimating on icraw (perplexity should improve on every iteration)
# 100%|██████████| 1/1 [00:00<00:00, 768.05it/s]
# INFO:eval:Cross-entropy: 1.2217 nats (= perplexity 3.393)
# 100%|██████████| 1/1 [00:00<00:00, 433.12it/s]
# 100%|██████████| 1/1 [00:00<00:00, 728.30it/s]
# INFO:eval:Cross-entropy: 1.0807 nats (= perplexity 2.947)
# 100%|██████████| 1/1 [00:00<00:00, 378.92it/s]
# 100%|██████████| 1/1 [00:00<00:00, 1024.75it/s]
# INFO:eval:Cross-entropy: 1.0576 nats (= perplexity 2.879)
# 100%|██████████| 1/1 [00:00<00:00, 403.22it/s]
# 100%|██████████| 1/1 [00:00<00:00, 1059.17it/s]
# INFO:eval:Cross-entropy: 1.0486 nats (= perplexity 2.854)
# 100%|██████████| 1/1 [00:00<00:00, 399.69it/s]
# 100%|██████████| 1/1 [00:00<00:00, 502.73it/s]
# INFO:eval:Cross-entropy: 1.0438 nats (= perplexity 2.840)
# 100%|██████████| 1/1 [00:00<00:00, 334.55it/s]
# 100%|██████████| 1/1 [00:00<00:00, 885.81it/s]
# INFO:eval:Cross-entropy: 1.0414 nats (= perplexity 2.833)
# 100%|██████████| 1/1 [00:00<00:00, 394.02it/s]
# 100%|██████████| 1/1 [00:00<00:00, 1012.87it/s]
# INFO:eval:Cross-entropy: 1.0402 nats (= perplexity 2.830)
# 100%|██████████| 1/1 [00:00<00:00, 384.02it/s]
# 100%|██████████| 1/1 [00:00<00:00, 638.99it/s]
# INFO:eval:Cross-entropy: 1.0396 nats (= perplexity 2.828)
# 100%|██████████| 1/1 [00:00<00:00, 410.64it/s]
# 100%|██████████| 1/1 [00:00<00:00, 892.03it/s]
# INFO:eval:Cross-entropy: 1.0394 nats (= perplexity 2.828)
# 100%|██████████| 1/1 [00:00<00:00, 445.44it/s]
# 100%|██████████| 1/1 [00:00<00:00, 1110.78it/s]
# INFO:eval:Cross-entropy: 1.0393 nats (= perplexity 2.827)
# 100%|██████████| 1/1 [00:00<00:00, 377.39it/s]
# 100%|██████████| 1/1 [00:00<00:00, 1079.89it/s]
# INFO:eval:Cross-entropy: 1.0392 nats (= perplexity 2.827)
# INFO:hmm:Saved model to my_hmm.pkl

# %%
log.info("*** A, B matrices after reestimation on icraw "
         "should match final params on spreadsheet [transposed])")
hmm.printAB()
# Out:
# INFO:test_ic:*** A, B matrices after reestimation on icraw should match final params on spreadsheet [transposed])
# Transition matrix A:
# 	C	H	_EOS_TAG_	_BOS_TAG_
# C	0.934	0.066	0.000	0.000
# H	0.072	0.865	0.063	0.000
# _EOS_TAG_	0.000	0.000	0.000	0.000
# _BOS_TAG_	0.000	1.000	0.000	0.000
#
# Emission matrix B:
# 	1	2	3
# C	0.641	0.148	0.211
# H	0.000	0.534	0.466
# _EOS_TAG_	0.000	0.000	0.000
# _BOS_TAG_	0.000	0.000	0.000

# %%
log.info("*** Viterbi results on icraw after reestimation on icraw")
icraw = TaggedCorpus(Path("icraw"), tagset=icsup.tagset, vocab=icsup.vocab)
write_tagging(hmm, icraw, Path("icraw_hmm.output"))  # calls hmm.viterbi_tagging on each sentence
os.system("cat icraw_hmm.output")   # print the file we just created
# Out:
# INFO:test_ic:*** Viterbi results on icraw after reestimation on icraw
# 100%|██████████| 1/1 [00:00<00:00, 646.07it/s]
# 2/H 3/H 3/H 2/H 3/H 2/H 3/H 2/H 2/H 3/H 1/C 3/C 3/C 1/C 1/C 1/C 2/C 1/C 1/C 1/C 3/C 1/C 2/C 1/C 1/C 1/C 2/H 3/H 3/H 2/H 3/H 2/H 2/H
# 0

# %% [markdown]
# Now let's try out a randomly initialized CRF on the ice cream data. Notice how
# the initialized A and B matrices now hold non-negative potentials,
# rather than probabilities that sum to 1.

# %%
log.info("*** Conditional Random Field (CRF) test\n")
crf = ConditionalRandomField(icsup.tagset, icsup.vocab)
log.info("*** Current A, B matrices (potentials from small random parameters)")
crf.printAB()
# Out:
# INFO:test_ic:*** Conditional Random Field (CRF) test
#
# INFO:test_ic:*** Current A, B matrices (potentials from small random parameters)
# Transition matrix A:
# 	C	H	_EOS_TAG_	_BOS_TAG_
# C	1.025	0.988	1.010	0.000
# H	0.984	0.987	1.007	0.000
# _EOS_TAG_	0.000	0.000	0.000	0.000
# _BOS_TAG_	0.996	0.996	0.990	0.000
#
# Emission matrix B:
# 	1	2	3
# C	1.014	0.993	0.988
# H	1.009	1.000	1.007
# _EOS_TAG_	0.000	0.000	0.000
# _BOS_TAG_	0.000	0.000	0.000

# %% [markdown]
# Now let's try your training code, running it on supervised data. To test this,
# we'll restart from a random initialization.
#
# Note that the logger reports the CRF's *conditional* cross-entropy,
# log p(tags | words) / n.  This is much lower than the HMM's *joint*
# cross-entropy log p(tags, words) / n, but that doesn't mean the CRF
# is worse at tagging.  The CRF is just predicting less information.

# %%
log.info("*** Supervised CRF training on icsup")
cross_entropy_loss = lambda model: model_cross_entropy(model, icsup)
crf.train(corpus=icsup, loss=cross_entropy_loss, lr=0.1, tolerance=0.0001)
log.info("*** A, B matrices after training on icsup")
crf.printAB()
# Out:
# INFO:test_ic:*** Supervised CRF training on icsup
# 100%|██████████| 4/4 [00:00<00:00, 1130.62it/s]
# INFO:eval:Cross-entropy: 0.6207 nats (= perplexity 1.860)
# 100%|██████████| 500/500 [00:00<00:00, 687.85it/s]
# 100%|██████████| 4/4 [00:00<00:00, 1630.76it/s]
# INFO:eval:Cross-entropy: 0.2042 nats (= perplexity 1.227)
# 100%|██████████| 500/500 [00:00<00:00, 703.98it/s]
# 100%|██████████| 4/4 [00:00<00:00, 1629.33it/s]
# INFO:eval:Cross-entropy: 0.2039 nats (= perplexity 1.226)
# 100%|██████████| 500/500 [00:00<00:00, 682.79it/s]
# 100%|██████████| 4/4 [00:00<00:00, 1382.78it/s]
# INFO:eval:Cross-entropy: 0.2019 nats (= perplexity 1.224)
# 100%|██████████| 500/500 [00:00<00:00, 708.61it/s]
# 100%|██████████| 4/4 [00:00<00:00, 1673.54it/s]
# INFO:eval:Cross-entropy: 0.2028 nats (= perplexity 1.225)
# 100%|██████████| 500/500 [00:00<00:00, 706.15it/s]
# 100%|██████████| 4/4 [00:00<00:00, 1453.45it/s]
# INFO:eval:Cross-entropy: 0.2021 nats (= perplexity 1.224)
# 100%|██████████| 500/500 [00:00<00:00, 713.06it/s]
# 100%|██████████| 4/4 [00:00<00:00, 1623.97it/s]
# INFO:eval:Cross-entropy: 0.2016 nats (= perplexity 1.223)
# 100%|██████████| 500/500 [00:00<00:00, 679.72it/s]
# 100%|██████████| 4/4 [00:00<00:00, 1572.96it/s]
# INFO:eval:Cross-entropy: 0.2015 nats (= perplexity 1.223)
# 100%|██████████| 500/500 [00:00<00:00, 694.64it/s]
# 100%|██████████| 4/4 [00:00<00:00, 1940.91it/s]
# INFO:eval:Cross-entropy: 0.2014 nats (= perplexity 1.223)
# 100%|██████████| 500/500 [00:00<00:00, 709.58it/s]
# 100%|██████████| 4/4 [00:00<00:00, 1694.84it/s]
# INFO:eval:Cross-entropy: 0.2018 nats (= perplexity 1.224)
# 100%|██████████| 500/500 [00:00<00:00, 705.90it/s]
# 100%|██████████| 4/4 [00:00<00:00, 1752.92it/s]
# INFO:eval:Cross-entropy: 0.2013 nats (= perplexity 1.223)
# 100%|██████████| 500/500 [00:00<00:00, 697.17it/s]
# 100%|██████████| 4/4 [00:00<00:00, 1318.34it/s]
# INFO:eval:Cross-entropy: 0.2021 nats (= perplexity 1.224)
# 100%|██████████| 500/500 [00:00<00:00, 705.53it/s]
# 100%|██████████| 4/4 [00:00<00:00, 1857.94it/s]
# INFO:eval:Cross-entropy: 0.2020 nats (= perplexity 1.224)
# 100%|██████████| 500/500 [00:00<00:00, 701.97it/s]
# 100%|██████████| 4/4 [00:00<00:00, 1734.62it/s]
# INFO:eval:Cross-entropy: 0.2014 nats (= perplexity 1.223)
# 100%|██████████| 500/500 [00:00<00:00, 723.70it/s]
# 100%|██████████| 4/4 [00:00<00:00, 1811.60it/s]
# INFO:eval:Cross-entropy: 0.2026 nats (= perplexity 1.225)
# 100%|██████████| 500/500 [00:00<00:00, 732.27it/s]
# 100%|██████████| 4/4 [00:00<00:00, 1974.25it/s]
# INFO:eval:Cross-entropy: 0.2015 nats (= perplexity 1.223)
# 100%|██████████| 500/500 [00:00<00:00, 733.63it/s]
# 100%|██████████| 4/4 [00:00<00:00, 1816.50it/s]
# INFO:eval:Cross-entropy: 0.2017 nats (= perplexity 1.223)
# 100%|██████████| 500/500 [00:00<00:00, 701.80it/s]
# 100%|██████████| 4/4 [00:00<00:00, 1797.05it/s]
# INFO:eval:Cross-entropy: 0.2014 nats (= perplexity 1.223)
# 100%|██████████| 500/500 [00:00<00:00, 726.94it/s]
# 100%|██████████| 4/4 [00:00<00:00, 1468.34it/s]
# INFO:eval:Cross-entropy: 0.2013 nats (= perplexity 1.223)
# 100%|██████████| 500/500 [00:00<00:00, 727.35it/s]
# 100%|██████████| 4/4 [00:00<00:00, 1645.31it/s]
# INFO:eval:Cross-entropy: 0.2011 nats (= perplexity 1.223)
# 100%|██████████| 500/500 [00:00<00:00, 672.82it/s]
# 100%|██████████| 4/4 [00:00<00:00, 1720.39it/s]
# INFO:eval:Cross-entropy: 0.2013 nats (= perplexity 1.223)
# 100%|██████████| 500/500 [00:00<00:00, 716.34it/s]
# 100%|██████████| 4/4 [00:00<00:00, 1686.32it/s]
# INFO:eval:Cross-entropy: 0.2021 nats (= perplexity 1.224)
# 100%|██████████| 500/500 [00:00<00:00, 685.16it/s]
# 100%|██████████| 4/4 [00:00<00:00, 1575.47it/s]
# INFO:eval:Cross-entropy: 0.2013 nats (= perplexity 1.223)
# 100%|██████████| 500/500 [00:00<00:00, 711.51it/s]
# 100%|██████████| 4/4 [00:00<00:00, 1731.57it/s]
# INFO:eval:Cross-entropy: 0.2022 nats (= perplexity 1.224)
# 100%|██████████| 500/500 [00:00<00:00, 705.84it/s]
# 100%|██████████| 4/4 [00:00<00:00, 1557.63it/s]
# INFO:eval:Cross-entropy: 0.2010 nats (= perplexity 1.223)
# 100%|██████████| 500/500 [00:00<00:00, 707.08it/s]
# 100%|██████████| 4/4 [00:00<00:00, 1691.42it/s]
# INFO:eval:Cross-entropy: 0.2018 nats (= perplexity 1.224)
# 100%|██████████| 500/500 [00:00<00:00, 690.55it/s]
# 100%|██████████| 4/4 [00:00<00:00, 1508.74it/s]
# INFO:eval:Cross-entropy: 0.2011 nats (= perplexity 1.223)
# 100%|██████████| 500/500 [00:00<00:00, 665.19it/s]
# 100%|██████████| 4/4 [00:00<00:00, 1787.28it/s]
# INFO:eval:Cross-entropy: 0.2011 nats (= perplexity 1.223)
# 100%|██████████| 500/500 [00:00<00:00, 691.95it/s]
# 100%|██████████| 4/4 [00:00<00:00, 1502.12it/s]
# INFO:eval:Cross-entropy: 0.2015 nats (= perplexity 1.223)
# 100%|██████████| 500/500 [00:00<00:00, 701.03it/s]
# 100%|██████████| 4/4 [00:00<00:00, 1577.99it/s]
# INFO:eval:Cross-entropy: 0.2016 nats (= perplexity 1.223)
# 100%|██████████| 500/500 [00:00<00:00, 673.80it/s]
# 100%|██████████| 4/4 [00:00<00:00, 1532.03it/s]
# INFO:eval:Cross-entropy: 0.2017 nats (= perplexity 1.223)
# 100%|██████████| 500/500 [00:00<00:00, 708.04it/s]
# 100%|██████████| 4/4 [00:00<00:00, 1560.67it/s]
# INFO:eval:Cross-entropy: 0.2011 nats (= perplexity 1.223)
# 100%|██████████| 500/500 [00:00<00:00, 710.32it/s]
# 100%|██████████| 4/4 [00:00<00:00, 1942.71it/s]
# INFO:eval:Cross-entropy: 0.2019 nats (= perplexity 1.224)
# 100%|██████████| 500/500 [00:00<00:00, 687.94it/s]
# 100%|██████████| 4/4 [00:00<00:00, 1785.00it/s]
# INFO:eval:Cross-entropy: 0.2017 nats (= perplexity 1.224)
# 100%|██████████| 500/500 [00:00<00:00, 694.17it/s]
# 100%|██████████| 4/4 [00:00<00:00, 1591.92it/s]
# INFO:eval:Cross-entropy: 0.2011 nats (= perplexity 1.223)
# 100%|██████████| 500/500 [00:00<00:00, 692.96it/s]
# 100%|██████████| 4/4 [00:00<00:00, 1845.88it/s]
# INFO:eval:Cross-entropy: 0.2014 nats (= perplexity 1.223)
# 100%|██████████| 500/500 [00:00<00:00, 703.41it/s]
# 100%|██████████| 4/4 [00:00<00:00, 1879.59it/s]
# INFO:eval:Cross-entropy: 0.2010 nats (= perplexity 1.223)
# 100%|██████████| 500/500 [00:00<00:00, 692.63it/s]
# 100%|██████████| 4/4 [00:00<00:00, 1806.92it/s]
# INFO:eval:Cross-entropy: 0.2019 nats (= perplexity 1.224)
# 100%|██████████| 500/500 [00:00<00:00, 665.69it/s]
# 100%|██████████| 4/4 [00:00<00:00, 1782.53it/s]
# INFO:eval:Cross-entropy: 0.2014 nats (= perplexity 1.223)
# 100%|██████████| 500/500 [00:00<00:00, 682.34it/s]
# 100%|██████████| 4/4 [00:00<00:00, 915.79it/s]
# INFO:eval:Cross-entropy: 0.2010 nats (= perplexity 1.223)
# 100%|██████████| 500/500 [00:00<00:00, 677.35it/s]
# 100%|██████████| 4/4 [00:00<00:00, 1716.69it/s]
# INFO:eval:Cross-entropy: 0.2010 nats (= perplexity 1.223)
# 100%|██████████| 500/500 [00:00<00:00, 716.52it/s]
# 100%|██████████| 4/4 [00:00<00:00, 1776.31it/s]
# INFO:eval:Cross-entropy: 0.2011 nats (= perplexity 1.223)
# 100%|██████████| 500/500 [00:00<00:00, 705.61it/s]
# 100%|██████████| 4/4 [00:00<00:00, 1564.89it/s]
# INFO:eval:Cross-entropy: 0.2012 nats (= perplexity 1.223)
# 100%|██████████| 500/500 [00:00<00:00, 708.56it/s]
# 100%|██████████| 4/4 [00:00<00:00, 1780.08it/s]
# INFO:eval:Cross-entropy: 0.2011 nats (= perplexity 1.223)
# 100%|██████████| 500/500 [00:00<00:00, 716.14it/s]
# 100%|██████████| 4/4 [00:00<00:00, 1518.03it/s]
# INFO:eval:Cross-entropy: 0.2016 nats (= perplexity 1.223)
# 100%|██████████| 500/500 [00:00<00:00, 690.75it/s]
# 100%|██████████| 4/4 [00:00<00:00, 1628.54it/s]
# INFO:eval:Cross-entropy: 0.2014 nats (= perplexity 1.223)
# 100%|██████████| 500/500 [00:00<00:00, 659.46it/s]
# 100%|██████████| 4/4 [00:00<00:00, 1779.32it/s]
# INFO:eval:Cross-entropy: 0.2011 nats (= perplexity 1.223)
# 100%|██████████| 500/500 [00:00<00:00, 666.77it/s]
# 100%|██████████| 4/4 [00:00<00:00, 1085.83it/s]
# INFO:eval:Cross-entropy: 0.2017 nats (= perplexity 1.223)
# 100%|██████████| 500/500 [00:00<00:00, 705.23it/s]
# 100%|██████████| 4/4 [00:00<00:00, 1575.47it/s]
# INFO:eval:Cross-entropy: 0.2010 nats (= perplexity 1.223)
# 100%|██████████| 500/500 [00:00<00:00, 712.22it/s]
# 100%|██████████| 4/4 [00:00<00:00, 1665.40it/s]
# INFO:eval:Cross-entropy: 0.2014 nats (= perplexity 1.223)
# 100%|██████████| 500/500 [00:00<00:00, 714.98it/s]
# 100%|██████████| 4/4 [00:00<00:00, 1892.10it/s]
# INFO:eval:Cross-entropy: 0.2014 nats (= perplexity 1.223)
# 100%|██████████| 500/500 [00:00<00:00, 719.52it/s]
# 100%|██████████| 4/4 [00:00<00:00, 1774.80it/s]
# INFO:eval:Cross-entropy: 0.2010 nats (= perplexity 1.223)
# 100%|██████████| 500/500 [00:00<00:00, 674.99it/s]
# 100%|██████████| 4/4 [00:00<00:00, 1612.88it/s]
# INFO:eval:Cross-entropy: 0.2010 nats (= perplexity 1.223)
# 100%|██████████| 500/500 [00:00<00:00, 635.54it/s]
# 100%|██████████| 4/4 [00:00<00:00, 1668.71it/s]
# INFO:eval:Cross-entropy: 0.2017 nats (= perplexity 1.224)
# 100%|██████████| 500/500 [00:00<00:00, 682.24it/s]
# 100%|██████████| 4/4 [00:00<00:00, 1612.88it/s]
# INFO:eval:Cross-entropy: 0.2017 nats (= perplexity 1.223)
# 100%|██████████| 500/500 [00:00<00:00, 693.55it/s]
# 100%|██████████| 4/4 [00:00<00:00, 1767.51it/s]
# INFO:eval:Cross-entropy: 0.2016 nats (= perplexity 1.223)
# 100%|██████████| 500/500 [00:00<00:00, 712.13it/s]
# 100%|██████████| 4/4 [00:00<00:00, 1659.14it/s]
# INFO:eval:Cross-entropy: 0.2010 nats (= perplexity 1.223)
# 100%|██████████| 500/500 [00:00<00:00, 703.70it/s]
# 100%|██████████| 4/4 [00:00<00:00, 1707.08it/s]
# INFO:eval:Cross-entropy: 0.2016 nats (= perplexity 1.223)
# 100%|██████████| 500/500 [00:00<00:00, 719.09it/s]
# 100%|██████████| 4/4 [00:00<00:00, 1698.44it/s]
# INFO:eval:Cross-entropy: 0.2020 nats (= perplexity 1.224)
# 100%|██████████| 500/500 [00:00<00:00, 684.19it/s]
# 100%|██████████| 4/4 [00:00<00:00, 1645.47it/s]
# INFO:eval:Cross-entropy: 0.2027 nats (= perplexity 1.225)
# 100%|██████████| 500/500 [00:00<00:00, 671.81it/s]
# 100%|██████████| 4/4 [00:00<00:00, 1300.46it/s]
# INFO:eval:Cross-entropy: 0.2018 nats (= perplexity 1.224)
# 100%|██████████| 500/500 [00:00<00:00, 697.32it/s]
# 100%|██████████| 4/4 [00:00<00:00, 1530.77it/s]
# INFO:eval:Cross-entropy: 0.2012 nats (= perplexity 1.223)
# 100%|██████████| 500/500 [00:00<00:00, 679.32it/s]
# 100%|██████████| 4/4 [00:00<00:00, 1755.86it/s]
# INFO:eval:Cross-entropy: 0.2010 nats (= perplexity 1.223)
# 100%|██████████| 500/500 [00:00<00:00, 707.54it/s]
# 100%|██████████| 4/4 [00:00<00:00, 1516.79it/s]
# INFO:eval:Cross-entropy: 0.2011 nats (= perplexity 1.223)
# 100%|██████████| 500/500 [00:00<00:00, 670.80it/s]
# 100%|██████████| 4/4 [00:00<00:00, 1437.27it/s]
# INFO:eval:Cross-entropy: 0.2011 nats (= perplexity 1.223)
# 100%|██████████| 500/500 [00:00<00:00, 686.52it/s]
# 100%|██████████| 4/4 [00:00<00:00, 1679.91it/s]
# INFO:eval:Cross-entropy: 0.2016 nats (= perplexity 1.223)
# 100%|██████████| 500/500 [00:00<00:00, 678.16it/s]
# 100%|██████████| 4/4 [00:00<00:00, 1526.17it/s]
# INFO:eval:Cross-entropy: 0.2021 nats (= perplexity 1.224)
# 100%|██████████| 500/500 [00:00<00:00, 702.72it/s]
# 100%|██████████| 4/4 [00:00<00:00, 1563.58it/s]
# INFO:eval:Cross-entropy: 0.2011 nats (= perplexity 1.223)
# 100%|██████████| 500/500 [00:00<00:00, 707.05it/s]
# 100%|██████████| 4/4 [00:00<00:00, 1698.27it/s]
# INFO:eval:Cross-entropy: 0.2012 nats (= perplexity 1.223)
# 100%|██████████| 500/500 [00:00<00:00, 710.28it/s]
# 100%|██████████| 4/4 [00:00<00:00, 1566.21it/s]
# INFO:eval:Cross-entropy: 0.2012 nats (= perplexity 1.223)
# 100%|██████████| 500/500 [00:00<00:00, 714.96it/s]
# 100%|██████████| 4/4 [00:00<00:00, 1597.53it/s]
# INFO:eval:Cross-entropy: 0.2015 nats (= perplexity 1.223)
# 100%|██████████| 500/500 [00:00<00:00, 681.85it/s]
# 100%|██████████| 4/4 [00:00<00:00, 1560.67it/s]
# INFO:eval:Cross-entropy: 0.2017 nats (= perplexity 1.224)
# 100%|██████████| 500/500 [00:00<00:00, 618.42it/s]
# 100%|██████████| 4/4 [00:00<00:00, 1818.08it/s]
# INFO:eval:Cross-entropy: 0.2020 nats (= perplexity 1.224)
# 100%|██████████| 500/500 [00:00<00:00, 647.24it/s]
# 100%|██████████| 4/4 [00:00<00:00, 1629.49it/s]
# INFO:eval:Cross-entropy: 0.2010 nats (= perplexity 1.223)
# 100%|██████████| 500/500 [00:00<00:00, 680.38it/s]
# 100%|██████████| 4/4 [00:00<00:00, 1795.31it/s]
# INFO:eval:Cross-entropy: 0.2025 nats (= perplexity 1.224)
# 100%|██████████| 500/500 [00:00<00:00, 682.49it/s]
# 100%|██████████| 4/4 [00:00<00:00, 1385.06it/s]
# INFO:eval:Cross-entropy: 0.2011 nats (= perplexity 1.223)
# 100%|██████████| 500/500 [00:00<00:00, 704.86it/s]
# 100%|██████████| 4/4 [00:00<00:00, 1651.46it/s]
# INFO:eval:Cross-entropy: 0.2029 nats (= perplexity 1.225)
# 100%|██████████| 500/500 [00:00<00:00, 678.75it/s]
# 100%|██████████| 4/4 [00:00<00:00, 1400.44it/s]
# INFO:eval:Cross-entropy: 0.2023 nats (= perplexity 1.224)
# 100%|██████████| 500/500 [00:00<00:00, 692.85it/s]
# 100%|██████████| 4/4 [00:00<00:00, 1636.64it/s]
# INFO:eval:Cross-entropy: 0.2016 nats (= perplexity 1.223)
# 100%|██████████| 500/500 [00:00<00:00, 640.24it/s]
# 100%|██████████| 4/4 [00:00<00:00, 1580.97it/s]
# INFO:eval:Cross-entropy: 0.2009 nats (= perplexity 1.223)
# 100%|██████████| 500/500 [00:00<00:00, 620.43it/s]
# 100%|██████████| 4/4 [00:00<00:00, 1697.76it/s]
# INFO:eval:Cross-entropy: 0.2020 nats (= perplexity 1.224)
# 100%|██████████| 500/500 [00:00<00:00, 626.84it/s]
# 100%|██████████| 4/4 [00:00<00:00, 716.30it/s]
# INFO:eval:Cross-entropy: 0.2009 nats (= perplexity 1.223)
# 100%|██████████| 500/500 [00:00<00:00, 674.28it/s]
# 100%|██████████| 4/4 [00:00<00:00, 1784.81it/s]
# INFO:eval:Cross-entropy: 0.2011 nats (= perplexity 1.223)
# 100%|██████████| 500/500 [00:00<00:00, 675.12it/s]
# 100%|██████████| 4/4 [00:00<00:00, 1490.38it/s]
# INFO:eval:Cross-entropy: 0.2015 nats (= perplexity 1.223)
# 100%|██████████| 500/500 [00:00<00:00, 681.09it/s]
# 100%|██████████| 4/4 [00:00<00:00, 1341.00it/s]
# INFO:eval:Cross-entropy: 0.2010 nats (= perplexity 1.223)
# 100%|██████████| 500/500 [00:00<00:00, 678.43it/s]
# 100%|██████████| 4/4 [00:00<00:00, 1737.67it/s]
# INFO:eval:Cross-entropy: 0.2017 nats (= perplexity 1.223)
# 100%|██████████| 500/500 [00:00<00:00, 655.87it/s]
# 100%|██████████| 4/4 [00:00<00:00, 1717.39it/s]
# INFO:eval:Cross-entropy: 0.2013 nats (= perplexity 1.223)
# 100%|██████████| 500/500 [00:00<00:00, 667.77it/s]
# 100%|██████████| 4/4 [00:00<00:00, 1520.92it/s]
# INFO:eval:Cross-entropy: 0.2012 nats (= perplexity 1.223)
# 100%|██████████| 500/500 [00:00<00:00, 685.90it/s]
# 100%|██████████| 4/4 [00:00<00:00, 1622.71it/s]
# INFO:eval:Cross-entropy: 0.2010 nats (= perplexity 1.223)
# 100%|██████████| 500/500 [00:00<00:00, 697.88it/s]
# 100%|██████████| 4/4 [00:00<00:00, 1563.14it/s]
# INFO:eval:Cross-entropy: 0.2012 nats (= perplexity 1.223)
# 100%|██████████| 500/500 [00:00<00:00, 695.02it/s]
# 100%|██████████| 4/4 [00:00<00:00, 1615.52it/s]
# INFO:eval:Cross-entropy: 0.2018 nats (= perplexity 1.224)
# 100%|██████████| 500/500 [00:00<00:00, 695.69it/s]
# 100%|██████████| 4/4 [00:00<00:00, 1809.25it/s]
# INFO:eval:Cross-entropy: 0.2025 nats (= perplexity 1.224)
# 100%|██████████| 500/500 [00:00<00:00, 658.72it/s]
# 100%|██████████| 4/4 [00:00<00:00, 1511.73it/s]
# INFO:eval:Cross-entropy: 0.2011 nats (= perplexity 1.223)
# 100%|██████████| 500/500 [00:00<00:00, 662.13it/s]
# 100%|██████████| 4/4 [00:00<00:00, 1625.23it/s]
# INFO:eval:Cross-entropy: 0.2011 nats (= perplexity 1.223)
# 100%|██████████| 500/500 [00:00<00:00, 645.93it/s]
# 100%|██████████| 4/4 [00:00<00:00, 1537.64it/s]
# INFO:eval:Cross-entropy: 0.2014 nats (= perplexity 1.223)
# 100%|██████████| 500/500 [00:00<00:00, 659.94it/s]
# 100%|██████████| 4/4 [00:00<00:00, 1572.23it/s]
# INFO:eval:Cross-entropy: 0.2010 nats (= perplexity 1.223)
# 100%|██████████| 500/500 [00:00<00:00, 631.13it/s]
# 100%|██████████| 4/4 [00:00<00:00, 1713.71it/s]
# INFO:eval:Cross-entropy: 0.2013 nats (= perplexity 1.223)
# 100%|██████████| 500/500 [00:00<00:00, 602.91it/s]
# 100%|██████████| 4/4 [00:00<00:00, 1532.59it/s]
# INFO:eval:Cross-entropy: 0.2012 nats (= perplexity 1.223)
# 100%|██████████| 500/500 [00:00<00:00, 690.03it/s]
# 100%|██████████| 4/4 [00:00<00:00, 1755.12it/s]
# INFO:eval:Cross-entropy: 0.2009 nats (= perplexity 1.223)
# 100%|██████████| 500/500 [00:00<00:00, 705.36it/s]
# 100%|██████████| 4/4 [00:00<00:00, 1552.87it/s]
# INFO:eval:Cross-entropy: 0.2012 nats (= perplexity 1.223)
# 100%|██████████| 500/500 [00:00<00:00, 700.24it/s]
# 100%|██████████| 4/4 [00:00<00:00, 1735.33it/s]
# INFO:eval:Cross-entropy: 0.2009 nats (= perplexity 1.223)
# INFO:hmm:Saved model to my_crf.pkl
# INFO:test_ic:*** A, B matrices after training on icsup
# Transition matrix A:
# 	C	H	_EOS_TAG_	_BOS_TAG_
# C	1.870	0.032	17.077	0.000
# H	9.479	1.730	0.060	0.000
# _EOS_TAG_	0.000	0.000	0.000	0.000
# _BOS_TAG_	0.057	17.496	0.990	0.000
#
# Emission matrix B:
# 	1	2	3
# C	59.142	0.966	0.017
# H	0.017	1.028	57.091
# _EOS_TAG_	0.000	0.000	0.000
# _BOS_TAG_	0.000	0.000	0.000

# %% [markdown]
# Let's again tag the spreadsheet "sentence" (that is, the sequence of ice
# creams) using the Viterbi algorithm.  The trained CRF might get a different
# answer than the trained HMM.  (Try comparing the two icraw_*.output files.)

# %%
log.info("*** Viterbi results on icraw with trained parameters")
icraw = TaggedCorpus(Path("icraw"), tagset=icsup.tagset, vocab=icsup.vocab)
write_tagging(crf, icraw, Path("icraw_crf.output"))  # calls hmm.viterbi_tagging on each sentence
os.system("cat icraw_crf.output")   # print the file we just created
# Out:
# INFO:test_ic:*** Viterbi results on icraw with trained parameters
# 100%|██████████| 1/1 [00:00<00:00, 335.25it/s]
# 2/H 3/H 3/H 2/H 3/H 2/H 3/H 2/H 2/H 3/H 1/C 3/H 3/H 1/C 1/C 1/C 2/C 1/C 1/C 1/C 3/H 1/C 2/C 1/C 1/C 1/C 2/C 3/H 3/H 2/H 3/H 2/C 2/C
# 0

# %%
crf.save_parameters(Path("crf_ic_params.pt"))
