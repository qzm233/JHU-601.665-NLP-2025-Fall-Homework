# %%
import torch
a = torch.ones(1, 10)
b = torch.ones(10, 10)
c = a @ b
c.size()
# Out:
# torch.Size([1, 10])

# %%
torch.eye(10)[:, 1:2].size()
# Out:
# torch.Size([10, 1])

# %%
c = torch.clamp(torch([0]), min=1e-45)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 c = torch.clamp(torch([0]), min=1e-45)
#
# TypeError: 'module' object is not callable
